# %% [markdown]
# Code created by: Yamid Felipe Quiroga González

# %%
#IMPORTED LIBRARIES
#requests is a library that allows us to make requests to APIS, this is essential for the project
#json is a library to modify the visual appearance of a json
#datetime is a library that contains time values, its use is mainly related to data access
#azurecosmos are libraries for connecting to the cosmos database in Azure, these allow us to access the database API to make queries
#os is a library that allows us to interact with the operating system where the program is executed
#uuid generate a unique UUID instead of using the current date and time. This ensures that each ID is unique.
import json, requests, os
from json.decoder import JSONDecodeError
from datetime import datetime
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from datetime import datetime
from windows_tools.installed_software import get_installed_software
import uuid

# %%
uri = "[INSERT_MONGO_DB_CONNECTION]"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

#Vulnerabilities.PcSoftwareCVE
# Selecciona la base de datos que deseas usar
db = client['[DATABASE]']
# Selecciona la colección que deseas usar
collection = db['[CONTAINER]']

db = collection.find()
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
def save_Mongo(json_data):
    try:
        collection.insert_one(json_data)
        print("JSON guardado exitosamente en MongoDB.")
    except Exception as e:
        print(f"Error al guardar JSON en MongoDB: {e}")

# %%
"""
Retrieves vulnerability information from the CVE Details API based on the specified software product ID and version ID.

Args:
    sw (str): The product ID of the software.
    vs (str): The version ID of the software.

Returns:
    dict: A dictionary containing vulnerability information retrieved from the API in JSON format.
"""
def apiVulnDb(sw, vs):

    url = f"https://www.cvedetails.com/api/v1/vulnerability/search?outputFormat=json&productId={sw}&versionId={vs}&pageNumber=1&resultsPerPage=20"

    payload = {}
    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'es-419,es;q=0.9,es-ES;q=0.8,en;q=0.7,en-GB;q=0.6,en-US;q=0.5,es-CO;q=0.4',
        'cache-control': 'max-age=0',
        'cookie': 'cvedconsent=2; prefs=%7B%22slp%22%3A1%7D; _ga=GA1.1.958340234.1710907803; ss=1; SSID=5nq5d56eqesmeolqoqv1t0eo0ouv6t11; _ga_3404JT2267=GS1.1.1712704969.5.1.1712706743.0.0.0',
        'if-modified-since': 'Wed, 13 Mar 2024 06:45:02 GMT',
        'referer': 'https://www.cvedetails.com/user/home',
        'sec-ch-ua': '"Microsoft Edge";v="123", "Not:A-Brand";v="8", "Chromium";v="123"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 Edg/123.0.0.0',
        'Authorization': 'Bearer 2b1eaac89175351535e321b970dd7704a3784026.eyJzdWIiOjM1NzQsImlhdCI6MTcxMzgzMTM0NCwiZXhwIjoxNzE1MDM5OTQwLCJraWQiOjEsImMiOiJIZzgxZ1ZYZzhLb2wrUzgxaGpUVzFKNms0OWFYQ3F6TXVXSERVVHZBaDNvMTNxXC9taGJZYVpjM2VMYnRpNnU1dDdNNU1sWXVQIn0='
    }

    response = requests.request("GET", url, headers=headers, data=payload)
    return response.json()

# %%
"""
Retrieves information about a specific CVE (Common Vulnerabilities and Exposures) entry from the MITRE CVE database.

Args:
    cve (str): The CVE ID to retrieve information for.

Returns:
    dict: A dictionary containing information about the specified CVE entry in JSON format.

"""
def apiCVE(cve):
    try:
        response = requests.get(f"https://cveawg.mitre.org/api/cve/{str(cve)}")
        
        # Verifica si la solicitud fue exitosa (código de estado 200)
        if response.status_code == 200:
            try:
                # Intenta decodificar la respuesta JSON
                data = response.json()
                return data
            except ValueError:
                # Si no se pudo decodificar la respuesta JSON, imprime un mensaje de error y devuelve None
                print("La respuesta no contiene datos JSON válidos.")
                return None
        elif response.status_code == 404:
            # Si el código de estado es 404, el recurso no fue encontrado
            print(f"El recurso para CVE {cve} no fue encontrado.")
            return None
        else:
            # Si la solicitud falla por alguna otra razón, imprime el código de estado y devuelve None
            print(f"Error en la solicitud. Código de estado: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        # Si ocurre un error durante la solicitud, imprime el mensaje de error y devuelve None
        print("Error durante la solicitud:", e)
        return None

# %%
"""
Retrieves the list of affected products for a given CVE (Common Vulnerabilities and Exposures) entry.

Args:
    cve (str): The CVE ID to retrieve affected products for.

Returns:
    list or str: A list containing the names of affected products, or 'not found' if no affected products are found.

"""
def get_affected_products(cve):
    # Load the JSON data for the CVE
    dataCVE = apiCVE(cve)

    # Check if the JSON data is None (indicating an error in fetching the data)
    if dataCVE is None:
        return 'not found'
    
    # Check if the JSON data contains an error message
    if 'error' in dataCVE and dataCVE['error'] == 'CVE_RECORD_DNE':
        return 'not found'
    
    # Check if the JSON data contains the list of affected products
    if 'containers' in dataCVE and 'cna' in dataCVE['containers'] and 'affected' in dataCVE['containers']['cna']:
        # Get the list of affected products from the JSON data
        affected_products = dataCVE['containers']['cna']['affected']
        
        # Create a list to store the product names
        product_list = []
        
        # Iterate over the list of affected products and extract the product names
        for affected_product in affected_products:
            if "product" in affected_product:
                product_list.append(affected_product['product'])
        
        # Return the list of products
        return product_list
    
    # If the JSON data doesn't contain the expected structure, return 'not found'
    return 'not found'

# %%
"""
Retrieves CVSS (Common Vulnerability Scoring System) metrics for a given CVE (Common Vulnerabilities and Exposures) entry from the OpenCVE API.

Args:
    cve (str): The CVE ID to retrieve CVSS metrics for.

Returns:
    dict: A dictionary containing CVSS metrics for the specified CVE entry in JSON format.
"""
def apiCVEmetric(cve):

    payload = {}
    headers = {
        #'Authorization': 'Basic WTRNMUQ6WWFtaWRPcGVuLjIwMDI='
        'Authorization': 'Basic NTdyb2xsZXI6NTdSb2xsZXIhMjAwMQ=='
    }
    url = f"https://www.opencve.io/api/cve/{cve}"
    response = requests.request("GET", url, headers=headers, data=payload)
    return response.json()

# %%
"""
Retrieves combined CVSS metrics for a given CVE (Common Vulnerabilities and Exposures) entry from the OpenCVE API.

Args:
    cve (str): The CVE ID to retrieve combined CVSS metrics for.

Returns:
    dict: A dictionary containing combined CVSS metrics for the specified CVE entry.

"""
def getCVSSmetrics(cve):

    response = apiCVEmetric(cve)

    baseScore = 0
    baseSeverity = "Null"
    
    # Primera opción: cvssMetricV31
    if "cvssMetricV31" in response["raw_nvd_data"]["metrics"]:
        cvss_metrics = response["raw_nvd_data"]["metrics"]["cvssMetricV31"][0]
        baseScore = cvss_metrics["cvssData"]["baseScore"]
        baseSeverity = cvss_metrics["cvssData"]["baseSeverity"]
    # Segunda opción: cvssMetricV30
    elif "cvssMetricV30" in response["raw_nvd_data"]["metrics"]:
        cvss_metrics = response["raw_nvd_data"]["metrics"]["cvssMetricV30"][0]
        baseScore = cvss_metrics["cvssData"]["baseScore"]
        baseSeverity = cvss_metrics["cvssData"]["baseSeverity"]
    # Tercera opción: cvssMetricV2
    elif "cvssMetricV2" in response["raw_nvd_data"]["metrics"]:
        cvss_metrics = response["raw_nvd_data"]["metrics"]["cvssMetricV2"][0]
        baseScore = cvss_metrics["cvssData"]["baseScore"]
        baseSeverity = cvss_metrics["baseSeverity"]
    else:
        print("No se encontró información de métricas CVSS.")
        cvss_metrics = None

    scoreMetric = {
        "baseScore": baseScore,
        "baseSeverity": baseSeverity
    }
    
    return scoreMetric

# %%
"""
Retrieves CVSS (Common Vulnerability Scoring System) metrics for a given CVE (Common Vulnerabilities and Exposures) entry from the OpenCVE API.

Args:
    cve (str): The CVE ID to retrieve CVSS metrics for.

Returns:
    dict: A dictionary containing CVSS metrics for the specified CVE entry in JSON format.
"""
def apiCVEmetric2(cve):
    url = f"https://services.nvd.nist.gov/rest/json/cves/2.0?cveId={cve}"
    payload = {}
    headers = {}

    try:
        response = requests.request("GET", url, headers=headers, data=payload)
        response_json = response.json()
    except JSONDecodeError:
        print(f"Error:")
        response_json = {}  # Valor predeterminado: un diccionario vacío
    
    return response_json

# %%
"""
Retrieves combined CVSS metrics for a given CVE (Common Vulnerabilities and Exposures) entry from the OpenCVE API.

Args:
    cve (str): The CVE ID to retrieve combined CVSS metrics for.

Returns:
    dict: A dictionary containing combined CVSS metrics for the specified CVE entry.

"""
def getCVSSmetrics2(cve):

    response = apiCVEmetric2(cve)

    baseScore = 0
    baseSeverity = "Null"
    
    if "vulnerabilities" in response:
        vulnerabilities = response["vulnerabilities"]
        for vulnerability in vulnerabilities:
            if "cve" in vulnerability and "metrics" in vulnerability["cve"]:
                metrics = vulnerability["cve"]["metrics"]
                if "cvssMetricV31" in metrics:
                    baseScore = metrics["cvssMetricV31"][0]["cvssData"]["baseScore"]
                    baseSeverity = metrics["cvssMetricV31"][0]["cvssData"]["baseSeverity"]
                elif "cvssMetricV30" in metrics:
                    baseScore = metrics["cvssMetricV30"][0]["cvssData"]["baseScore"]
                    baseSeverity = metrics["cvssMetricV30"][0]["cvssData"]["baseSeverity"]
                elif "cvssMetricV2" in metrics:
                    baseScore = metrics["cvssMetricV2"][0]["cvssData"]["baseScore"]
                    baseSeverity = metrics["cvssMetricV2"][0]["baseSeverity"]
                    

    scoreMetric = {
        "baseScore": baseScore,
        "baseSeverity": baseSeverity
    }
    
    return scoreMetric

# %%
"""
Saves a JSON document in the Cosmos DB container.

Args:
    Swjson (dict): The JSON document to be saved.
"""
def saveJSON(Swjson):
    # Save the json in the container
    try:
        container = db.get_container_client(CONTAINER_ID)
        container.create_item(body = Swjson)
        print("Items already saved")
    except exceptions.CosmosResourceExistsError:
        print("Something wrong saving items")

# %%
def getVulnersCVE(software):
    url = 'https://vulners.com/api/v3/search/lucene/'
    query = f"software:'{software}'"
    params = {
        "query": query,
        "size" : 4
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Lanza una excepción si la respuesta indica un error HTTP
        data = response.json()
        
        # Verifica si la respuesta contiene datos
        if "data" in data and "search" in data["data"]:
            cve_list = []
            # Recorre cada índice en la lista search
            for item in data["data"]["search"]:
                # Obtiene la lista de cvelist en cada índice
                cvelist = item.get("_source", {}).get("cvelist", [])
                # Extiende la lista cve_list con los elementos de cvelist
                cve_list.extend(cvelist)
            return cve_list
        else:
            print("La respuesta no contiene los datos esperados:", data)
            return []
    except requests.RequestException as e:
        print("Error al realizar la solicitud:", e)
        return []

# %%
"""


"""
def seachSWVulnerabilities(product):

    cve_list = getVulnersCVE(product)

    swVulnerabilities = []
    
    # Access each element within 'cve_list'
    for cve in cve_list:
        print(cve)
        vulnerability = {
            "cve": cve,
            "affect": get_affected_products(cve), 
            "metrics": getCVSSmetrics2(cve)
        }
        swVulnerabilities.append(vulnerability) 
    
    return swVulnerabilities

# %%
def getPcDataBase():
    url = "https://us-east-1.aws.data.mongodb-api.com/app/data-bcurboy/endpoint/data/v1/action/find"
     
    payload = "{\r\n    \"collection\":\"softwareByIP\",\r\n    \"database\":\"vulnsData\",\r\n    \"dataSource\":\"Cluster0\",\r\n    \"filter\": {}\r\n}'"
    headers = {
      'Content-Type': 'application/ejson',
      'apiKey': '8zblZqSy1gtnZqmSd8YCsyHqXuMmzCfMdKaa22xY5lc8RzVQMGfEF3W3Lwt6Y2G1'
    }
     
    response = requests.request("POST", url, headers=headers, data=payload)
     
    return response.json()

# %%
def save_txt(json_data):
    ruta = r"C:\Users\Yamid\Documents\archivo.txt"
    try:
        with open(ruta, 'w') as archivo:
            archivo.write(json.dumps(json_data, indent=4))
        print("JSON guardado como archivo de texto en:", ruta)
    except Exception as e:
        print("Error al guardar el JSON como archivo de texto:", e)

# %%
"""

"""
def seachPCSoftwareVulnerabilities(pc):

    # Build the JSON document to be saved in the DB
    swVulnerabilities = {
        'pc': f"{pc['hostname']}",
        'operativeSystem': pc["operativeSystem"],
        "softwares": [],
        "analysisDate": datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }
    print(pc["hostname"])
    # Accede al nombre de cada índice dentro de 'softwareData'
    for software_entry in pc["softwareData"]:
        name = software_entry["Name"]
        print(name)
        if name != "Atmel Segger USB Drivers (501e)":
            software = {
                "software": name,
                "vulnerabilities": seachSWVulnerabilities(name)
            }
            swVulnerabilities['softwares'].append(software)
    # Printthe JSON result
    print(json.dumps(swVulnerabilities, indent=4))
    
    # Save data
    save_Mongo(swVulnerabilities)
    save_txt(swVulnerabilities)

# %%
for i in range(0, 18):
#0,1,2,3,4,6,7,8
    seachPCSoftwareVulnerabilities(getPcDataBase()['documents'][i])
# Out:
# DESKTOP-FHV7QBV
# Python 3.12.2 Tcl/Tk Support (64-bit debug)
# Python 3.12.2 Standard Library (64-bit debug)
# Python 3.12.2 Executables (64-bit debug)
# Python 3.12.2 Executables (64-bit symbols)
# Python 3.12.2 Development Libraries (64-bit debug)
# Python 3.12.2 Standard Library (64-bit symbols)
# Microsoft Teams Meeting Add-in for Microsoft Office
# CVE-2024-21374
# CVE-2024-29054
# CVE-2024-29053
# CVE-2024-29055
# Python 3.12.2 Standard Library (64-bit)
# Python 3.12.2 Tcl/Tk Support (64-bit symbols)
# Python 3.12.2 Test Suite (64-bit symbols)
# Python 3.12.2 Core Interpreter (64-bit debug)
# CVE-2024-31868
# CVE-2024-31864
# CVE-2024-31868
# Python 3.12.2 Executables (64-bit)
# Python 3.12.2 Test Suite (64-bit debug)
# Python 3.12.2 Core Interpreter (64-bit symbols)
# CVE-2024-31868
# CVE-2024-31864
# CVE-2024-31868
# Python 3.12.2 Test Suite (64-bit)
# Python 3.12.2 Tcl/Tk Support (64-bit)
# Python 3.12.2 Documentation (64-bit)
# Python 3.12.2 Add to Path (64-bit)
# CVE-2023-22943
# Python 3.12.2 pip Bootstrap (64-bit)
# CVE-2023-5752
# CVE-2023-5752
# CVE-2023-5752
# Python 3.12.2 Development Libraries (64-bit)
# Python 3.12.2 Core Interpreter (64-bit)
# CVE-2024-31868
# CVE-2024-31864
# CVE-2024-31868
# Office 16 Click-to-Run Extensibility Component
# CVE-2010-10007
# CVE-2024-32866
# CVE-2006-4242
# CVE-2006-4556
# CVE-2006-4378
# Office 16 Click-to-Run Localization Component
# CVE-2024-31983
# CVE-2012-10014
# CVE-2012-10013
# CVE-2010-10007
# Office 16 Click-to-Run Licensing Component
# CVE-2010-10007
# CVE-2024-32866
# CVE-2006-4242
# CVE-2006-4556
# CVE-2006-4378
# Microsoft .NET Framework 4.5.1 Multi-Targeting Pack
# CVE-2024-21312
# Microsoft .NET Framework 4.5.2 Multi-Targeting Pack (ENU)
# CVE-2024-21312
# SQL Server 2022 Database Engine Services
# CVE-2024-20332
# CVE-2022-46337
# CVE-2024-20368
# CVE-2024-29056
# Microsoft .NET AppHost Pack - 6.0.0 Rc 2 (x64_arm64)
# CVE-2024-21319
# Microsoft Visual C++ 2022 X86 Additional Runtime - 14.32.31326
# CVE-2024-0056
# CVE-2024-0057
# CVE-2024-21386
# CVE-2024-21404
# vs_tipsmsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# windows_toolscorepkg
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft ASP.NET Diagnostic Pack for Visual Studio
# CVE-2024-21386
# CVE-2024-21404
# CVE-2024-20656
# CVE-2024-0057
# Paquete acumulativo de Intellisense de Microsoft .NET Framework para Visual Studio (español)
# CVE-2024-21319
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-0057
# Microsoft Visual Studio 2015 Shell (Isolated) Resources
# CVE-2024-20656
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# Windows SDK for Windows Store Apps Metadata
# CVE-2024-27793
# CVE-2021-20373
# Windows Desktop Extension SDK Contracts
# CVE-2017-18017
# CVE-2024-34073
# CVE-2017-6099
# CVE-2017-20175
# SQL Server 2022 XEvent
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-21345
# vs_minshellmsires
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Visual Studio 2015 XAML Designer - ENU
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-0057
# CVE-2024-21386
# MSI Development Tools
# CVE-2006-4349
# CVE-2023-22943
# CVE-2024-4128
# CVE-2016-15012
# Windows SDK for Windows Store Apps
# CVE-2024-27793
# CVE-2021-20373
# Microsoft .NET Framework 4.5 Multi-Targeting Pack
# CVE-2024-21312
# Python 3.9.5 Development Libraries (64-bit)
# WinRT Intellisense UAP - en-us
# CVE-2024-22039
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# SQL Server 2022 Shared Management Objects
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-0056
# Microsoft .NET Framework 4.8 Targeting Pack
# CVE-2024-21312
# Microsoft Build Tools 14.0 (x86)
# CVE-2024-2215
# CVE-2024-2216
# CVE-2024-21409
# CVE-2024-21409
# Microsoft .NET CoreRuntime For CoreCon
# CVE-2024-21319
# CVE-2024-29054
# CVE-2024-29053
# CVE-2024-29055
# Windows SDK Desktop Tools x64
# CVE-2023-4692
# CVE-2023-4693
# CVE-2024-1048
# CVE-2022-2601
# CVE-2022-2601
# CVE-2023-4692
# CVE-2023-4693
# CVE-2024-1048
# Microsoft ASP.NET Core 6.0.0 RC 2 Build rc.2.21480.10 Shared Framework (x64)
# CVE-2024-21386
# CVE-2024-21404
# CVE-2024-0916
# CVE-2024-2215
# Microsoft Visual C++ 2013 x86 Minimum Runtime - 12.0.40664
# CVE-2024-26190
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-21392
# Microsoft Web Deploy 4.0
# CVE-2024-23280
# CVE-2024-23284
# CVE-2023-42950
# CVE-2024-23252
# CVE-2023-42843
# CVE-2024-23263
# CVE-2024-23254
# CVE-2023-42956
# CVE-2015-4053
# CVE-2015-3010
# CVE-2023-41419
# Microsoft.NET.Sdk.Android.Manifest-6.0.100
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Python 3.9.5 Tcl/Tk Support (64-bit symbols)
# Microsoft ASP.NET Core 6.0.0 RC 2 Build rc.2.21480.10 Targeting Pack (x64)
# CVE-2024-21386
# CVE-2024-21404
# vs_communityx64msi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# SQL Server 2022 Database Engine Services
# CVE-2024-20332
# CVE-2022-46337
# CVE-2024-20368
# CVE-2024-29056
# vs_devenvsharedmsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# SQL Server 2022 Database Engine Shared
# CVE-2022-46337
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# Windows SDK for Windows Store Apps Libs
# CVE-2024-27793
# CVE-2021-20373
# Microsoft.NET.Sdk.Maui.Manifest-6.0.100
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft .NET Runtime - 6.0.0 Rc 2 (x86)
# CVE-2024-26190
# CVE-2024-21392
# CVE-2024-21319
# CVE-2024-21409
# Visual C++ Library CRT ARM64 Appx Package
# CVE-2023-1579
# CVE-2022-24512
# CVE-2014-9984
# CVE-2015-20109
# CVE-2018-11236
# CVE-2021-3999
# CVE-2024-2961
# CVE-2024-2961
# Microsoft .NET Framework 4.5.1 Multi-Targeting Pack (ENU)
# CVE-2024-21312
# SQL Server 2022 Connection Info
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# vs_clickoncebootstrappermsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Comprobación de estado de PC Windows
# CVE-2006-7006
# CVE-2024-1695
# CVE-2022-42265
# CVE-2024-0071
# CVE-2024-0073
# CVE-2024-0075
# CVE-2024-0078
# vs_Graphics_Singletonx86
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Analysis Services OLE DB Provider
# CVE-2023-36728
# CVE-2024-34447
# CVE-2014-8089
# Windows SDK Modern Non-Versioned Developer Tools
# CVE-2023-33850
# CVE-2024-20918
# CVE-2024-20919
# CVE-2024-20921
# CVE-2024-20926
# CVE-2024-20945
# CVE-2024-20952
# CVE-2024-4128
# CVE-2023-21938
# CVE-2023-21968
# CVE-2023-2597
# CVE-2022-44020
# Microsoft Update Health Tools
# CVE-2024-4128
# CVE-2022-44020
# CVE-2022-44020
# CVE-2023-21253
# Microsoft Visual C++ 2013 x86 Debug Runtime - 12.0.21005
# CVE-2024-26190
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# IntelliTraceProfilerProxy
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Azure Authoring Tools - v2.9.7
# CVE-2024-21397
# CVE-2024-21329
# CVE-2024-20667
# CVE-2024-20679
# Microsoft Visual Studio Setup WMI Provider
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-21386
# Visual Studio 2015 Prerequisites - ENU Language Pack
# CVE-2024-20656
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# SQL Server 2022 Connection Info
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# Microsoft Visual Studio Tools for Applications 2019 x64 Hosting Support
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-0057
# CVE-2024-21386
# Microsoft Visual Studio Services Hub
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-21386
# SQL Server 2022 Database Engine Services
# CVE-2024-20332
# CVE-2022-46337
# CVE-2024-20368
# CVE-2024-29056
# Microsoft Windows Desktop Runtime - 6.0.0 Rc 2 (x64)
# CVE-2024-21392
# CVE-2024-26190
# CVE-2024-29988
# CVE-2024-29061
# Python 3.9.5 Test Suite (64-bit symbols)
# Microsoft Windows Desktop Runtime - 6.0.0 Rc 2 (x86)
# CVE-2024-26190
# CVE-2024-21392
# CVE-2024-29988
# CVE-2024-29052
# Windows SDK for Windows Store Apps Contracts
# CVE-2024-27793
# CVE-2021-20373
# Microsoft ASP.NET Core Module for IIS Express
# CVE-2024-21386
# CVE-2024-21404
# CVE-2022-4963
# CVE-2021-28141
# vs_SQLClickOnceBootstrappermsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft.NET.Workload.Emscripten.Manifest
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Visual Studio Tools for Applications 2019 x86 Hosting Support
# CVE-2024-20656
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# Microsoft Visual C++ 2022 X86 Debug Runtime - 14.30.30704
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# CVE-2024-21404
# Xamarin Remoted iOS Simulator
# CVE-2024-20373
# El recurso para CVE CVE-2024-20373 no fue encontrado.
# CVE-2024-20306
# CVE-2024-20259
# CVE-2024-20311
# Windows SDK Desktop Libs arm64
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# CVE-2024-21409
# Universal CRT Extension SDK
# CVE-2023-1579
# CVE-2024-34073
# CVE-2017-6099
# CVE-2023-44487
# SQL Server 2022 Common Files
# CVE-2024-29056
# CVE-2023-44487
# CVE-2023-44487
# CVE-2024-29988
# Microsoft Visual Studio Setup Configuration
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-0057
# CVE-2024-21386
# Windows SDK
# CVE-2024-34073
# CVE-2017-6099
# CVE-2023-44487
# CVE-2017-6217
# Visual C++ Library CRT Appx Resource Package
# CVE-2023-1579
# CVE-2014-9984
# CVE-2015-20109
# CVE-2018-11236
# CVE-2021-3999
# CVE-2024-2961
# CVE-2024-2961
# CVE-2023-5676
# Microsoft .NET CoreRuntime SDK
# CVE-2024-21319
# CVE-2024-21312
# CVE-2023-45288
# CVE-2023-45288
# Epic Games Launcher Prerequisites (x64)
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# CVE-2023-40546
# CVE-2023-40547
# CVE-2023-40548
# CVE-2023-40549
# CVE-2023-40550
# CVE-2023-40551
# Microsoft .NET Framework 4.5.2 Multi-Targeting Pack
# CVE-2024-21312
# SQL Server 2022 Database Engine Services
# CVE-2022-46337
# CVE-2024-20332
# CVE-2024-20368
# CVE-2024-29056
# Java 8 Update 401 (64-bit)
# Microsoft Visual Studio 2015 Shell (Minimum) Interop Assemblies
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-21386
# Java SE Development Kit 8 Update 301 (64-bit)
# CVE-2013-2465
# CVE-2011-3571
# CVE-2012-0507
# CVE-2023-22943
# CVE-2016-15012
# Python 3.9.5 Standard Library (64-bit)
# vs_filehandler_amd64
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# SQL Server 2022 Full text search
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-21345
# Microsoft .NET Framework 4.8 SDK
# CVE-2024-21312
# CVE-2024-21319
# CVE-2024-34467
# CVE-2023-45288
# vs_minshellsharedmsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# SQL Server 2022 Shared Management Objects Extensions
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2023-39683
# SQL Server Management Studio
# CVE-2024-0056
# CVE-2023-36728
# CVE-2023-48788
# CVE-2023-2565
# Microsoft TestPlatform SDK Local Feed
# CVE-2023-44487
# CVE-2023-36260
# CVE-2024-34073
# SQL Server 2022 Database Engine Services
# CVE-2022-46337
# CVE-2024-20332
# CVE-2024-20368
# CVE-2024-29056
# Microsoft System CLR Types for SQL Server 2014
# CVE-2023-36728
# vs_minshellx64msi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# icecap_collection_neutral
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Analysis Services OLE DB Provider
# CVE-2023-36728
# CVE-2024-34447
# CVE-2014-8089
# Atmel LibUSB0 Driver (x64)
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# CVE-2023-40546
# CVE-2023-40547
# CVE-2023-40548
# CVE-2023-40549
# CVE-2023-40550
# CVE-2023-40551
# Microsoft Visual Studio 2015 Shell (Minimum)
# CVE-2024-20656
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# Windows SDK Desktop Libs x86
# CVE-2024-21409
# CVE-2024-21409
# CVE-2024-21409
# CVE-2022-24512
# Atmel Segger USB Drivers (501e)
# Windows SDK Desktop Headers x86
# CVE-2024-21409
# CVE-2024-21409
# CVE-2024-21409
# CVE-2022-24512
# Microsoft Visual C++ 2022 X64 Additional Runtime - 14.32.31326
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# CVE-2024-21404
# Browser for SQL Server 2022
# CVE-2023-36728
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# Python 3.9.5 Standard Library (64-bit symbols)
# Windows SDK Redistributables
# CVE-2024-34073
# CVE-2017-6099
# CVE-2023-44487
# CVE-2017-6217
# Microsoft.NET.Sdk.MacCatalyst.Manifest-6.0.100
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Help Viewer 2.3
# CVE-2023-6185
# CVE-2023-6186
# CVE-2024-23672
# CVE-2023-1370
# CVE-2015-10108
# Microsoft Visual C++ 2013 x64 Additional Runtime - 12.0.21005
# CVE-2024-21392
# CVE-2024-26190
# CVE-2024-0057
# CVE-2024-20656
# Paquete de compatibilidad de Microsoft .NET Framework 4.8 (español)
# CVE-2006-7006
# CVE-2024-21312
# CVE-2024-21319
# CVE-2024-34467
# Microsoft Visual Studio 2015 Shell (Minimum) Resources
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-21386
#  Tools for .Net 3.5
# CVE-2023-30441
# CVE-2024-4128
# CVE-2023-45288
# CVE-2023-50164
# Microsoft SQL Server 2022 Setup (English)
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-0056
# Adobe Refresh Manager
# CVE-2017-11468
# CVE-2021-32760
# CVE-2021-41103
# CVE-2021-43784
# CVE-2021-43816
# CVE-2022-23471
# CVE-2022-23648
# CVE-2022-29162
# CVE-2022-31030
# CVE-2022-42969
# CVE-2023-2253
# CVE-2023-25153
# CVE-2023-25173
# CVE-2023-25809
# CVE-2023-26136
# CVE-2023-26159
# CVE-2023-27561
# CVE-2023-28155
# CVE-2023-28642
# CVE-2023-28840
# CVE-2023-28841
# CVE-2023-28842
# CVE-2023-29827
# CVE-2023-39326
# CVE-2023-45283
# CVE-2023-45284
# CVE-2023-45285
# CVE-2024-3661
# CVE-2023-45142
# Adobe Acrobat Reader - Español
# CVE-2024-20726
# CVE-2024-20727
# CVE-2024-20728
# CVE-2024-20729
# CVE-2024-20730
# CVE-2024-20731
# CVE-2024-20733
# CVE-2024-20734
# CVE-2024-20735
# CVE-2024-20736
# CVE-2024-20747
# CVE-2024-20748
# CVE-2024-20749
# CVE-2024-20765
# CVE-2024-30301
# CVE-2024-30302
# CVE-2024-30303
# CVE-2024-30304
# CVE-2024-30305
# CVE-2024-30306
# CVE-2023-21608
# CVE-2024-20735
# CVE-2024-20736
# MySQL Server 8.0
# CVE-2024-21050
# CVE-2024-21013
# CVE-2024-21062
# CVE-2024-21057
# Windows SDK Desktop Tools x86
# CVE-2024-21409
# CVE-2024-21409
# CVE-2024-4128
# CVE-2024-21409
# Universal CRT Redistributable
# CVE-2023-1579
# CVE-2022-35252
# CVE-2022-32207
# CVE-2022-32208
# icecap_collectionresourcesx64
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Azure Libraries for .NET – v2.9
# CVE-2024-21319
# CVE-2024-21397
# CVE-2024-21329
# Python 3.9.5 Executables (64-bit)
# Microsoft .NET Targeting Pack - 6.0.0 Rc 2 (x64)
# CVE-2024-21319
# SQL Server 2022 DMF
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-21345
# SDK ARM Redistributables
# CVE-2022-24512
# CVE-2022-48251
# CVE-2024-34073
# CVE-2017-6099
# Microsoft Visual C++ 2008 Redistributable - x86 9.0.30729.6161
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-21386
# Microsoft Visual C++ 2013 x64 Minimum Runtime - 12.0.21005
# CVE-2024-21392
# CVE-2024-26190
# CVE-2024-0057
# CVE-2024-20656
# Python 3.9.5 Utility Scripts (64-bit)
# Microsoft Build Tools Language Resources 14.0 (amd64)
# CVE-2023-2565
# CVE-2023-49568
# CVE-2024-2215
# Windows SDK DirectX x64 Remote
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# CVE-2023-40546
# CVE-2023-40547
# CVE-2023-40548
# CVE-2023-40549
# CVE-2023-40550
# CVE-2023-40551
# Windows SDK Desktop Headers arm
# CVE-2022-24512
# CVE-2022-48251
# CVE-2024-34073
# CVE-2017-6099
# Microsoft.NET.Workload.Mono.Toolchain.Manifest
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Windows App Certification Kit SupportedApiList x86
# CVE-2023-22943
# CVE-2024-21409
# CVE-2024-21409
# CVE-2016-15012
# Visual C++ Library CRT Desktop Appx Package
# CVE-2023-1579
# CVE-2014-9984
# CVE-2015-20109
# CVE-2018-11236
# CVE-2021-3999
# CVE-2024-2961
# CVE-2024-2961
# CVE-2023-5676
# WinRT Intellisense Desktop - Other Languages
# CVE-2013-2465
# CVE-2011-3571
# CVE-2012-0507
# CVE-2017-16232
# CVE-2023-1370
# Microsoft System CLR Types para SQL Server 2019
# CVE-2023-36728
# CVE-2024-29056
# CVE-2022-38028
# CVE-2024-20662
# Microsoft .NET AppHost Pack - 6.0.0 Rc 2 (x64_x86)
# CVE-2024-21319
# Python 3.9.5 Core Interpreter (64-bit symbols)
# CVE-2024-31868
# CVE-2024-31864
# CVE-2024-31868
# Universal General MIDI DLS Extension SDK
# CVE-2024-34073
# CVE-2017-6099
# CVE-2023-44487
# CVE-2017-20175
# WinRT Intellisense IoT - Other Languages
# CVE-2024-29053
# CVE-2024-29055
# CVE-2024-29054
# CVE-2023-28567
# Universal CRT Tools x86
# CVE-2023-1579
# CVE-2024-21409
# CVE-2024-21409
# CVE-2024-4128
# WinAppDeploy
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# vs_minshellinteropx64msi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft .NET Framework 4.6 Targeting Pack
# CVE-2024-21312
# Proteus 8 Professional
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-21068
# Python 3.9.5 Tcl/Tk Support (64-bit)
# SSMS Post Install Tasks
# CVE-2018-25058
# CVE-2018-25058
# CVE-2024-0530
# CVE-2024-0528
# Microsoft NetStandard SDK
# CVE-2024-34073
# CVE-2023-44487
# CVE-2017-6099
# Microsoft UniversalWindowsPlatform SDK
# CVE-2024-34073
# CVE-2017-6099
# CVE-2023-44487
# CVE-2017-6217
# WinRT Intellisense PPI - Other Languages
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Visual C++ Library CRT Appx Package
# CVE-2023-1579
# CVE-2014-9984
# CVE-2015-20109
# CVE-2018-11236
# CVE-2021-3999
# CVE-2024-2961
# CVE-2024-2961
# CVE-2023-5676
# Microsoft.NET.Sdk.tvOS.Manifest-6.0.100
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# VS JIT Debugger
# CVE-2023-21267
# CVE-2023-1370
# CVE-2024-3858
# CVE-2024-21634
# Microsoft Visual C++ 2013 x64 Debug Runtime - 12.0.21005
# CVE-2024-21392
# CVE-2024-26190
# CVE-2024-20656
# CVE-2024-0056
# Microsoft Command Line Utilities 15 for SQL Server
# CVE-2023-36728
# vs_devenx64vmsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# vs_BlendMsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Visual C++ 2022 X64 Debug Runtime - 14.30.30704
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# CVE-2024-21404
# Update for Windows 10 for x64-based Systems (KB5001716)
# CVE-2022-4318
# CVE-2024-27793
# Microsoft Build Tools Language Resources 14.0 (x86)
# CVE-2023-2565
# CVE-2023-49568
# CVE-2024-2215
# SQL Server 2022 Database Engine Shared
# CVE-2022-46337
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# Application Verifier x64 External Package
# CVE-2022-20454
# CVE-2023-21287
# VS Immersive Activate Helper
# CVE-2023-21267
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# SQL Server 2022 SQL Diagnostics
# CVE-2023-36728
# CVE-2024-29056
# CVE-2024-0056
# CVE-2024-29988
# Microsoft.NET.Sdk.iOS.Manifest-6.0.100
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft VSS Writer for SQL Server 2022
# CVE-2024-29056
# CVE-2023-36728
# CVE-2024-29988
# CVE-2024-29052
# vs_Graphics_Singletonx64
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Kits Configuration Installer
# CVE-2024-29133
# CVE-2024-29131
# CVE-2023-50740
# CVE-2024-29131
# CVE-2024-29133
# Microsoft .NET Framework 4 Multi-Targeting Pack
# CVE-2024-21312
# Visual C++ Library CRT Desktop Appx Package
# CVE-2023-1579
# CVE-2014-9984
# CVE-2015-20109
# CVE-2018-11236
# CVE-2021-3999
# CVE-2024-2961
# CVE-2024-2961
# CVE-2023-5676
# Microsoft SQL Server 2019 LocalDB
# CVE-2023-36728
# CVE-2024-29056
# CVE-2022-38028
# CVE-2024-20662
# vs_filehandler_x86
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# IntelliTraceProfilerProxy
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# IIS 10.0 Express
# CVE-2024-29041
# CVE-2017-20160
# CVE-2024-29041
# CVE-2020-3921
# Windows SDK Modern Versioned Developer Tools
# CVE-2023-33850
# CVE-2024-20918
# CVE-2024-20919
# CVE-2024-20921
# CVE-2024-20926
# CVE-2024-20945
# CVE-2024-20952
# CVE-2024-4128
# CVE-2023-21938
# CVE-2023-21968
# CVE-2023-2597
# CVE-2022-44020
# vs_FileTracker_Singleton
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Build of OpenJDK con Hotspot 11.0.12+7 (x64)
# CVE-2024-2215
# CVE-2024-2216
# CVE-2022-24512
# CVE-2022-24512
# vs_communitymsires
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Windows SDK for Windows Store Managed Apps Libs
# CVE-2024-27793
# CVE-2021-20373
# SQL Server 2022 Batch Parser
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-21345
# SQL Server 2022 XEvent
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-21345
# Atmel Driver Files
# CVE-2019-25084
# CVE-2024-1597
# CVE-2024-1597
# Windows SDK Facade Windows WinMD Versioned
# CVE-2024-29988
# CVE-2024-29061
# Windows IoT Extension SDK Contracts
# CVE-2024-29053
# CVE-2024-29055
# CVE-2024-29054
# CVE-2024-34073
# Microsoft OLE DB Driver for SQL Server
# CVE-2023-36728
# None
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Azure PowerShell - April 2018
# CVE-2024-0057
# CVE-2024-21397
# CVE-2024-21329
# CVE-2024-20667
# Python 3.9.5 Test Suite (64-bit)
# Microsoft SQL Server 2022 RsFx Driver
# CVE-2023-36728
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# vs_CoreEditorFonts
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Windows SDK Desktop Headers arm64
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# CVE-2024-21409
# SQL Server 2022 Database Engine Services
# CVE-2024-20332
# CVE-2022-46337
# CVE-2024-20368
# CVE-2024-29056
# Visual C++ Library CRT Appx Package
# CVE-2023-1579
# CVE-2014-9984
# CVE-2015-20109
# CVE-2018-11236
# CVE-2021-3999
# CVE-2024-2961
# CVE-2024-2961
# CVE-2023-5676
# Paquete de compatibilidad de Microsoft .NET Framework 4.7.2 (español)
# CVE-2006-7006
# CVE-2024-21312
# CVE-2024-21319
# CVE-2024-34467
# Microsoft ASP.NET Core 6.0.0 RC 2 Build rc.2.21480.10 Shared Framework (x86)
# CVE-2024-21386
# CVE-2024-21404
# CVE-2024-0916
# CVE-2024-2215
# Microsoft Visual Studio 2015 XAML Designer
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-21386
# icecap_collectionresources
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# fx-ES PLUS Emulator Subscription for fx-82/85/350ES PLUS 2nd edition
# CVE-2023-6401
# CVE-2023-2039
# CVE-2023-2041
# CVE-2023-1606
# Universal CRT Headers Libraries and Sources
# CVE-2023-1579
# CVE-2023-30441
# CVE-2023-50164
# CVE-2024-20310
# ClickOnce Bootstrapper Package for Microsoft .NET Framework
# CVE-2024-21312
# CVE-2024-21319
# CVE-2023-5676
# CVE-2024-29054
# Windows SDK DirectX x86 Remote
# CVE-2024-21409
# CVE-2024-21409
# CVE-2024-21409
# CVE-2022-24512
# Windows Team Extension SDK
# CVE-2024-34073
# CVE-2017-6099
# CVE-2023-44487
# CVE-2017-20175
# Oracle VM VirtualBox 7.0.14
# CVE-2013-2465
# CVE-2011-3571
# CVE-2012-0507
# CVE-2024-21103
# CVE-2024-21106
# CVE-2024-21107
# CVE-2024-21108
# CVE-2024-21109
# CVE-2024-21110
# CVE-2024-21111
# CVE-2024-21112
# CVE-2024-21113
# CVE-2024-21114
# CVE-2024-21115
# CVE-2024-21116
# CVE-2024-21121
# CVE-2018-19183
# Microsoft Help Viewer 2.2
# CVE-2023-6185
# CVE-2023-6186
# CVE-2024-23672
# CVE-2023-24998
# CVE-2023-28709
# CVE-2023-1370
# icecap_collection_x64
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# SQL Server 2022 Shared Management Objects
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-0056
# Microsoft .NET Toolset 6.0.100-rc.2.21505.57 (x64)
# CVE-2024-21319
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# Windows Desktop Extension SDK
# CVE-2017-18017
# CVE-2024-34073
# CVE-2017-6099
# CVE-2017-20175
# SQL Server 2022 Shared Management Objects Extensions
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2023-39683
# Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.32.31326
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# CVE-2024-21404
# Windows SDK Desktop Tools arm64
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# CVE-2024-21409
# Microsoft ASP.NET Core Module V2 for IIS Express
# CVE-2024-21386
# CVE-2024-21404
# CVE-2023-6597
# CVE-2022-4963
# Windows App Certification Kit Native Components
# CVE-2023-22943
# CVE-2016-4567
# CVE-2023-21118
# CVE-2023-21094
# SQL Server 2022 Database Engine Services
# CVE-2024-20332
# CVE-2022-46337
# CVE-2024-20368
# CVE-2024-29056
# Windows SDK for Windows Store Apps DirectX x86 Remote
# CVE-2024-27793
# CVE-2021-20373
# Java(TM) SE Development Kit 16.0.2 (64-bit)
# CVE-2013-2465
# CVE-2011-3571
# CVE-2012-0507
# CVE-2023-22943
# CVE-2016-15012
# Python 3.9.5 Documentation (64-bit)
# Microsoft Build Tools 14.0 (amd64)
# CVE-2024-2215
# CVE-2024-2216
# CVE-2024-4128
# CVE-2024-2216
# Microsoft.NET.Sdk.macOS.Manifest-6.0.100
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Python 3.9.5 pip Bootstrap (64-bit)
# CVE-2023-5752
# CVE-2023-5752
# CVE-2023-5752
# Windows SDK Desktop Libs arm
# CVE-2022-24512
# CVE-2022-48251
# CVE-2024-34073
# CVE-2024-21392
# Visual C++ Library CRT Desktop Appx Package
# CVE-2023-1579
# CVE-2014-9984
# CVE-2015-20109
# CVE-2018-11236
# CVE-2021-3999
# CVE-2024-2961
# CVE-2024-2961
# CVE-2023-5676
# Universal CRT Tools x64
# CVE-2023-1579
# CVE-2023-4692
# CVE-2023-4693
# CVE-2024-1048
# CVE-2022-2601
# CVE-2023-4692
# CVE-2023-4693
# CVE-2024-1048
# Integration Services
# CVE-2022-46337
# CVE-2024-20332
# CVE-2024-20368
# Windows SDK Signing Tools
# CVE-2024-4128
# CVE-2022-44020
# CVE-2022-44020
# CVE-2024-34073
# vs_clickoncesigntoolmsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Windows Mobile Extension SDK
# CVE-2016-15012
# CVE-2024-34073
# CVE-2023-44487
# CVE-2017-6099
# Microsoft .NET Host FX Resolver - 6.0.0 Rc 2 (x86)
# CVE-2019-10190
# CVE-2019-10191
# CVE-2019-19331
# CVE-2020-12667
# CVE-2019-10190
# CVE-2019-10191
# CVE-2024-21319
# CVE-2023-5676
# MySQL Installer - Community
# CVE-2017-1000009
# CVE-2022-42344
# CVE-2022-42344
# Windows SDK for Windows Store Apps Tools
# CVE-2024-27793
# CVE-2021-20373
# Microsoft .NET Standard Targeting Pack - 2.1.0 (x64)
# CVE-2024-21319
# Python 3.9.5 Executables (64-bit symbols)
# Visual Studio 2015 Prerequisites
# CVE-2024-20656
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# MySQL Connector J
# CVE-2017-3590
# CVE-2017-3590
# CVE-2024-21090
# CVE-2024-4536
# SQL Server 2022 Common Files
# CVE-2024-29056
# CVE-2023-44487
# CVE-2022-4899
# CVE-2023-21911
# CVE-2023-21919
# CVE-2023-21920
# CVE-2023-21929
# CVE-2023-21933
# CVE-2023-21935
# CVE-2023-21940
# CVE-2023-21945
# CVE-2023-21946
# CVE-2023-21947
# CVE-2023-21953
# CVE-2023-21955
# CVE-2023-21962
# CVE-2023-21966
# CVE-2023-21972
# CVE-2023-21976
# CVE-2023-21977
# CVE-2023-21980
# CVE-2023-21982
# CVE-2023-22005
# CVE-2023-22007
# CVE-2023-22008
# CVE-2023-22032
# CVE-2023-22033
# CVE-2023-22038
# CVE-2023-22046
# CVE-2023-22048
# CVE-2023-22053
# CVE-2023-22054
# CVE-2023-22056
# CVE-2023-22057
# CVE-2023-22058
# CVE-2023-22059
# CVE-2023-22064
# CVE-2023-22065
# CVE-2023-22066
# CVE-2023-22068
# CVE-2023-22070
# CVE-2023-22078
# CVE-2023-22079
# CVE-2023-22084
# CVE-2023-22092
# CVE-2023-22097
# CVE-2023-22103
# CVE-2023-22104
# CVE-2023-22110
# CVE-2023-22111
# CVE-2023-22112
# CVE-2023-22113
# CVE-2023-22114
# CVE-2023-22115
# CVE-2024-20960
# CVE-2024-20961
# CVE-2024-20962
# CVE-2024-20963
# CVE-2024-20964
# CVE-2024-20965
# CVE-2024-20966
# CVE-2024-20967
# CVE-2024-20968
# CVE-2024-20969
# CVE-2024-20970
# CVE-2024-20971
# CVE-2024-20972
# CVE-2024-20973
# CVE-2024-20974
# CVE-2024-20976
# CVE-2024-20977
# CVE-2024-20978
# CVE-2024-20981
# CVE-2024-20982
# CVE-2024-20983
# CVE-2024-20984
# CVE-2024-20985
# CVE-2024-20993
# CVE-2024-21015
# CVE-2024-21049
# CVE-2024-21050
# CVE-2024-21051
# CVE-2024-21052
# CVE-2024-21053
# CVE-2024-21055
# CVE-2024-21056
# CVE-2024-21057
# CVE-2024-21061
# CVE-2023-44487
# SQL Server Management Studio Language Pack - English
# CVE-2023-2565
# CVE-2023-49568
# Microsoft Azure Compute Emulator - v2.9.7
# CVE-2024-21397
# CVE-2024-21329
# CVE-2024-20667
# CVE-2024-20679
# Microsoft Windows Desktop Targeting Pack - 6.0.0 Rc 2 (x64)
# CVE-2024-29988
# WinRT Intellisense IoT - en-us
# CVE-2024-29053
# CVE-2024-29055
# CVE-2024-29054
# CVE-2024-22039
# SQL Server 2022 Database Engine Services
# CVE-2022-46337
# CVE-2024-20332
# CVE-2024-20368
# CVE-2024-29056
# Microsoft ODBC Driver 17 for SQL Server
# CVE-2023-36728
# DiagnosticsHub_CollectionService
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# vs_communitysharedmsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# vs_minshellinteropsharedmsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Windows SDK AddOn
# CVE-2024-34073
# CVE-2017-6099
# CVE-2023-44487
# CVE-2017-6217
# Microsoft .NET 6.0 Templates 6.0.100-rc.2.21505.57 (x64)
# CVE-2024-21319
# CVE-2022-24512
# CVE-2022-24512
# Microsoft Visual C++ 2013 x86 Additional Runtime - 12.0.40664
# CVE-2024-26190
# CVE-2024-21392
# CVE-2024-0057
# CVE-2024-20656
# Microsoft Visual C++ 2008 Redistributable - x86 9.0.30729.17
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-21386
# Microsoft .NET Native SDK
# CVE-2024-21319
# CVE-2023-21118
# CVE-2023-21094
# CVE-2024-21312
# Microsoft .NET Host FX Resolver - 6.0.0 Rc 2 (x64)
# CVE-2019-10190
# CVE-2019-10191
# CVE-2019-10190
# CVE-2019-10191
# CVE-2019-19331
# CVE-2020-12667
# CVE-2024-21319
# CVE-2023-5676
# Windows SDK Desktop Libs x64
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# CVE-2023-40546
# CVE-2023-40547
# CVE-2023-40548
# CVE-2023-40549
# CVE-2023-40550
# CVE-2023-40551
# Windows SDK EULA
# CVE-2024-34073
# CVE-2017-6099
# CVE-2023-44487
# CVE-2017-6217
# Microsoft .NET Framework 4.5.1 SDK
# CVE-2024-21312
# CVE-2024-21319
# CVE-2024-34467
# CVE-2023-45288
# Windows Mobile Extension SDK Contracts
# CVE-2016-15012
# CVE-2024-34073
# CVE-2023-44487
# CVE-2017-6099
# Windows SDK Desktop Headers x64
# CVE-2022-24512
# CVE-2022-24512
# CVE-2023-40546
# CVE-2023-40547
# CVE-2023-40548
# CVE-2023-40549
# CVE-2023-40550
# CVE-2023-40551
# CVE-2024-21409
# Python 3.9.5 Core Interpreter (64-bit)
# CVE-2024-31868
# CVE-2024-31864
# CVE-2024-31868
# VS Script Debugging Common
# CVE-2024-22201
# CVE-2024-27140
# CVE-2024-30564
# CVE-2024-22201
# Microsoft .NET Framework 4.7.2 Targeting Pack
# CVE-2024-21312
# Microsoft .NET Framework 4.8 SDK (español)
# CVE-2024-21312
# CVE-2024-21319
# CVE-2024-34467
# CVE-2023-45288
# Windows SDK ARM Desktop Tools
# CVE-2024-4128
# CVE-2022-24512
# CVE-2022-44020
# CVE-2022-44020
# WinRT Intellisense UAP - Other Languages
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# WinRT Intellisense Mobile - en-us
# CVE-2024-22039
# CVE-2016-15012
# CVE-2018-25080
# CVE-2023-42261
# Python Launcher
# CVE-2024-34073
# CVE-2024-0450
# CVE-2024-21319
# CVE-2024-33664
# CVE-2023-6597
# Atmel WinUSB
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft Visual Studio 2015 Shell (Isolated)
# CVE-2024-20656
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# SQL Server 2022 DMF
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-0056
# Microsoft .NET AppHost Pack - 6.0.0 Rc 2 (x64)
# CVE-2024-21319
# SDK ARM Additions
# CVE-2022-24512
# CVE-2022-48251
# CVE-2024-34073
# CVE-2024-21392
# Entity Framework 6.2.0 Tools  for Visual Studio 2022
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# CVE-2024-21404
# Windows SDK for Windows Store Apps Headers
# CVE-2024-27793
# CVE-2021-20373
# WinRT Intellisense Desktop - en-us
# CVE-2024-22039
# CVE-2017-16232
# CVE-2013-2465
# CVE-2011-3571
# CVE-2012-0507
# Visual Studio 2017 Isolated Shell for SSMS
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-0057
# CVE-2024-21404
# Microsoft SQL Server 2014 Management Objects
# CVE-2023-36728
# Java Auto Updater
# CVE-2019-17449
# CVE-2023-7093
# CVE-2023-1277
# CVE-2013-2465
# Microsoft .NET SDK 6.0.100-rc.2.21505.57 (x64) from Visual Studio
# CVE-2024-21319
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.32.31326
# CVE-2024-0057
# CVE-2024-0056
# CVE-2024-21386
# CVE-2024-21404
# vs_clickoncebootstrappermsires
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft .NET AppHost Pack - 6.0.0 Rc 2 (x64_arm)
# CVE-2024-21319
# MySQL Workbench 8.0 CE
# CVE-2022-2925
# CVE-2024-21000
# CVE-2024-20993
# CVE-2024-21061
# Windows Team Extension SDK Contracts
# CVE-2024-34073
# CVE-2023-44487
# CVE-2017-6099
# CVE-2017-20175
# vcpp_crt.redist.clickonce
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Microsoft .NET Runtime - 6.0.0 Rc 2 (x64)
# CVE-2024-21392
# CVE-2024-26190
# CVE-2024-21319
# CVE-2024-21386
# Windows App Certification Kit x64
# CVE-2023-22943
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# Windows IoT Extension SDK
# CVE-2024-29053
# CVE-2024-29055
# CVE-2024-29054
# CVE-2024-34073
# Microsoft .NET Host - 6.0.0 Rc 2 (x64)
# CVE-2024-21319
# CVE-2023-5676
# CVE-2022-24512
# CVE-2022-24512
# WinRT Intellisense PPI - en-us
# CVE-2024-22039
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# {
#     "pc": "DESKTOP-FHV7QBV",
#     "operativeSystem": "Windows",
#     "softwares": [
#         {
#             "software": "Python 3.12.2 Tcl/Tk Support (64-bit debug)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Standard Library (64-bit debug)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Executables (64-bit debug)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Executables (64-bit symbols)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Development Libraries (64-bit debug)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Standard Library (64-bit symbols)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Microsoft Teams Meeting Add-in for Microsoft Office",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-21374",
#                     "affect": [
#                         "Microsoft Teams for Android"
#                     ],
#                     "metrics": {
#                         "baseScore": 5.0,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-29054",
#                     "affect": [
#                         "Microsoft Defender for IoT"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.2,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-29053",
#                     "affect": [
#                         "Microsoft Defender for IoT"
#                     ],
#                     "metrics": {
#                         "baseScore": 8.8,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-29055",
#                     "affect": [
#                         "Microsoft Defender for IoT"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.2,
#                         "baseSeverity": "HIGH"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Python 3.12.2 Standard Library (64-bit)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Tcl/Tk Support (64-bit symbols)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Test Suite (64-bit symbols)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Core Interpreter (64-bit debug)",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-31868",
#                     "affect": [
#                         "Apache Zeppelin"
#                     ],
#                     "metrics": {
#                         "baseScore": 0,
#                         "baseSeverity": "Null"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-31864",
#                     "affect": [
#                         "Apache Zeppelin"
#                     ],
#                     "metrics": {
#                         "baseScore": 0,
#                         "baseSeverity": "Null"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-31868",
#                     "affect": [
#                         "Apache Zeppelin"
#                     ],
#                     "metrics": {
#                         "baseScore": 0,
#                         "baseSeverity": "Null"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Python 3.12.2 Executables (64-bit)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Test Suite (64-bit debug)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Core Interpreter (64-bit symbols)",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-31868",
#                     "affect": [
#                         "Apache Zeppelin"
#                     ],
#                     "metrics": {
#                         "baseScore": 0,
#                         "baseSeverity": "Null"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-31864",
#                     "affect": [
#                         "Apache Zeppelin"
#                     ],
#                     "metrics": {
#                         "baseScore": 0,
#                         "baseSeverity": "Null"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-31868",
#                     "affect": [
#                         "Apache Zeppelin"
#                     ],
#                     "metrics": {
#                         "baseScore": 0,
#                         "baseSeverity": "Null"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Python 3.12.2 Test Suite (64-bit)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Tcl/Tk Support (64-bit)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Documentation (64-bit)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Add to Path (64-bit)",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2023-22943",
#                     "affect": [
#                         "Splunk Add-on Builder",
#                         "Splunk CloudConnect SDK"
#                     ],
#                     "metrics": {
#                         "baseScore": 5.3,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Python 3.12.2 pip Bootstrap (64-bit)",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2023-5752",
#                     "affect": [
#                         "pip"
#                     ],
#                     "metrics": {
#                         "baseScore": 3.3,
#                         "baseSeverity": "LOW"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2023-5752",
#                     "affect": [
#                         "pip"
#                     ],
#                     "metrics": {
#                         "baseScore": 3.3,
#                         "baseSeverity": "LOW"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2023-5752",
#                     "affect": [
#                         "pip"
#                     ],
#                     "metrics": {
#                         "baseScore": 3.3,
#                         "baseSeverity": "LOW"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Python 3.12.2 Development Libraries (64-bit)",
#             "vulnerabilities": []
#         },
#         {
#             "software": "Python 3.12.2 Core Interpreter (64-bit)",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-31868",
#                     "affect": [
#                         "Apache Zeppelin"
#                     ],
#                     "metrics": {
#                         "baseScore": 0,
#                         "baseSeverity": "Null"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-31864",
#                     "affect": [
#                         "Apache Zeppelin"
#                     ],
#                     "metrics": {
#                         "baseScore": 0,
#                         "baseSeverity": "Null"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-31868",
#                     "affect": [
#                         "Apache Zeppelin"
#                     ],
#                     "metrics": {
#                         "baseScore": 0,
#                         "baseSeverity": "Null"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Office 16 Click-to-Run Extensibility Component",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2010-10007",
#                     "affect": [
#                         "click-reminder"
#                     ],
#                     "metrics": {
#                         "baseScore": 9.8,
#                         "baseSeverity": "CRITICAL"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-32866",
#                     "affect": [
#                         "conform"
#                     ],
#                     "metrics": {
#                         "baseScore": 8.6,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2006-4242",
#                     "affect": [
#                         "n/a"
#                     ],
#                     "metrics": {
#                         "baseScore": 5.1,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2006-4556",
#                     "affect": [
#                         "n/a"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2006-4378",
#                     "affect": [
#                         "n/a"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Office 16 Click-to-Run Localization Component",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-31983",
#                     "affect": [
#                         "xwiki-platform"
#                     ],
#                     "metrics": {
#                         "baseScore": 9.9,
#                         "baseSeverity": "CRITICAL"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2012-10014",
#                     "affect": [
#                         "Backend Localization Plugin"
#                     ],
#                     "metrics": {
#                         "baseScore": 6.1,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2012-10013",
#                     "affect": [
#                         "Backend Localization Plugin"
#                     ],
#                     "metrics": {
#                         "baseScore": 6.1,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2010-10007",
#                     "affect": [
#                         "click-reminder"
#                     ],
#                     "metrics": {
#                         "baseScore": 9.8,
#                         "baseSeverity": "CRITICAL"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Office 16 Click-to-Run Licensing Component",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2010-10007",
#                     "affect": [
#                         "click-reminder"
#                     ],
#                     "metrics": {
#                         "baseScore": 9.8,
#                         "baseSeverity": "CRITICAL"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-32866",
#                     "affect": [
#                         "conform"
#                     ],
#                     "metrics": {
#                         "baseScore": 8.6,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2006-4242",
#                     "affect": [
#                         "n/a"
#                     ],
#                     "metrics": {
#                         "baseScore": 5.1,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2006-4556",
#                     "affect": [
#                         "n/a"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2006-4378",
#                     "affect": [
#                         "n/a"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Microsoft .NET Framework 4.5.1 Multi-Targeting Pack",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-21312",
#                     "affect": [
#                         "Microsoft .NET Framework 3.5 AND 4.8.1",
#                         "Microsoft .NET Framework 4.8",
#                         "Microsoft .NET Framework 3.5 AND 4.8",
#                         "Microsoft .NET Framework 3.5 AND 4.7.2",
#                         "Microsoft .NET Framework 4.6.2/4.7/4.7.1/4.7.2",
#                         "Microsoft .NET Framework 3.5"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Microsoft .NET Framework 4.5.2 Multi-Targeting Pack (ENU)",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-21312",
#                     "affect": [
#                         "Microsoft .NET Framework 3.5 AND 4.8.1",
#                         "Microsoft .NET Framework 4.8",
#                         "Microsoft .NET Framework 3.5 AND 4.8",
#                         "Microsoft .NET Framework 3.5 AND 4.7.2",
#                         "Microsoft .NET Framework 4.6.2/4.7/4.7.1/4.7.2",
#                         "Microsoft .NET Framework 3.5"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "SQL Server 2022 Database Engine Services",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-20332",
#                     "affect": [
#                         "Cisco Identity Services Engine Software"
#                     ],
#                     "metrics": {
#                         "baseScore": 5.5,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2022-46337",
#                     "affect": [
#                         "Apache Derby"
#                     ],
#                     "metrics": {
#                         "baseScore": 9.8,
#                         "baseSeverity": "CRITICAL"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-20368",
#                     "affect": [
#                         "Cisco Identity Services Engine Software"
#                     ],
#                     "metrics": {
#                         "baseScore": 6.5,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-29056",
#                     "affect": [
#                         "Windows Server 2019",
#                         "Windows Server 2019 (Server Core installation)",
#                         "Windows Server 2022",
#                         "Windows Server 2022, 23H2 Edition (Server Core installation)",
#                         "Windows Server 2016",
#                         "Windows Server 2016 (Server Core installation)",
#                         "Windows Server 2008 Service Pack 2",
#                         "Windows Server 2008 Service Pack 2 (Server Core installation)",
#                         "Windows Server 2008  Service Pack 2",
#                         "Windows Server 2008 R2 Service Pack 1",
#                         "Windows Server 2008 R2 Service Pack 1 (Server Core installation)",
#                         "Windows Server 2012",
#                         "Windows Server 2012 (Server Core installation)",
#                         "Windows Server 2012 R2",
#                         "Windows Server 2012 R2 (Server Core installation)"
#                     ],
#                     "metrics": {
#                         "baseScore": 4.3,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Microsoft .NET AppHost Pack - 6.0.0 Rc 2 (x64_arm64)",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-21319",
#                     "affect": [
#                         ".NET 6.0",
#                         "Microsoft Visual Studio 2022 version 17.2",
#                         "Microsoft Visual Studio 2022 version 17.6",
#                         "Microsoft Visual Studio 2022 version 17.4",
#                         "Microsoft Visual Studio 2022 version 17.8",
#                         ".NET 7.0",
# ...
#                         "Red Hat Enterprise Linux 9.2 Extended Update Support"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.4,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2023-40549",
#                     "affect": [
#                         "Red Hat Enterprise Linux 7",
#                         "Red Hat Enterprise Linux 7",
#                         "Red Hat Enterprise Linux 8",
#                         "Red Hat Enterprise Linux 8.2 Advanced Update Support",
#                         "Red Hat Enterprise Linux 8.2 Telecommunications Update Service",
#                         "Red Hat Enterprise Linux 8.2 Update Services for SAP Solutions",
#                         "Red Hat Enterprise Linux 8.4 Advanced Mission Critical Update Support",
#                         "Red Hat Enterprise Linux 8.4 Telecommunications Update Service",
#                         "Red Hat Enterprise Linux 8.4 Update Services for SAP Solutions",
#                         "Red Hat Enterprise Linux 8.6 Extended Update Support",
#                         "Red Hat Enterprise Linux 8.8 Extended Update Support",
#                         "Red Hat Enterprise Linux 8.8 Extended Update Support",
#                         "Red Hat Enterprise Linux 9",
#                         "Red Hat Enterprise Linux 9.0 Extended Update Support",
#                         "Red Hat Enterprise Linux 9.0 Extended Update Support",
#                         "Red Hat Enterprise Linux 9.0 Extended Update Support",
#                         "Red Hat Enterprise Linux 9.2 Extended Update Support"
#                     ],
#                     "metrics": {
#                         "baseScore": 5.5,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2023-40550",
#                     "affect": [
#                         "Red Hat Enterprise Linux 7",
#                         "Red Hat Enterprise Linux 7",
#                         "Red Hat Enterprise Linux 8",
#                         "Red Hat Enterprise Linux 8.2 Advanced Update Support",
#                         "Red Hat Enterprise Linux 8.2 Telecommunications Update Service",
#                         "Red Hat Enterprise Linux 8.2 Update Services for SAP Solutions",
#                         "Red Hat Enterprise Linux 8.4 Advanced Mission Critical Update Support",
#                         "Red Hat Enterprise Linux 8.4 Telecommunications Update Service",
#                         "Red Hat Enterprise Linux 8.4 Update Services for SAP Solutions",
#                         "Red Hat Enterprise Linux 8.6 Extended Update Support",
#                         "Red Hat Enterprise Linux 8.8 Extended Update Support",
#                         "Red Hat Enterprise Linux 8.8 Extended Update Support",
#                         "Red Hat Enterprise Linux 9",
#                         "Red Hat Enterprise Linux 9.0 Extended Update Support",
#                         "Red Hat Enterprise Linux 9.0 Extended Update Support",
#                         "Red Hat Enterprise Linux 9.0 Extended Update Support",
#                         "Red Hat Enterprise Linux 9.2 Extended Update Support"
#                     ],
#                     "metrics": {
#                         "baseScore": 5.5,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2023-40551",
#                     "affect": [
#                         "Red Hat Enterprise Linux 7",
#                         "Red Hat Enterprise Linux 7",
#                         "Red Hat Enterprise Linux 8",
#                         "Red Hat Enterprise Linux 8.2 Advanced Update Support",
#                         "Red Hat Enterprise Linux 8.2 Telecommunications Update Service",
#                         "Red Hat Enterprise Linux 8.2 Update Services for SAP Solutions",
#                         "Red Hat Enterprise Linux 8.4 Advanced Mission Critical Update Support",
#                         "Red Hat Enterprise Linux 8.4 Telecommunications Update Service",
#                         "Red Hat Enterprise Linux 8.4 Update Services for SAP Solutions",
#                         "Red Hat Enterprise Linux 8.6 Extended Update Support",
#                         "Red Hat Enterprise Linux 8.8 Extended Update Support",
#                         "Red Hat Enterprise Linux 8.8 Extended Update Support",
#                         "Red Hat Enterprise Linux 9",
#                         "Red Hat Enterprise Linux 9.0 Extended Update Support",
#                         "Red Hat Enterprise Linux 9.0 Extended Update Support",
#                         "Red Hat Enterprise Linux 9.0 Extended Update Support",
#                         "Red Hat Enterprise Linux 9.2 Extended Update Support"
#                     ],
#                     "metrics": {
#                         "baseScore": 5.1,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "Microsoft .NET Runtime - 8.0.2 (x86)",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2024-26190",
#                     "affect": [
#                         "Microsoft Visual Studio 2022 version 17.9",
#                         "Windows Server 2022",
#                         "Windows 11 version 21H2",
#                         "Windows 11 version 22H2",
#                         "Windows 11 version 22H3",
#                         "Windows 11 Version 23H2",
#                         "Windows Server 2022, 23H2 Edition (Server Core installation)",
#                         "PowerShell 7.3",
#                         "PowerShell 7.4",
#                         "Microsoft Visual Studio 2022 version 17.4",
#                         "Microsoft Visual Studio 2022 version 17.6",
#                         "Microsoft Visual Studio 2022 version 17.8",
#                         ".NET 7.0",
#                         ".NET 8.0"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-21392",
#                     "affect": [
#                         "Microsoft Visual Studio 2022 version 17.9",
#                         "PowerShell 7.3",
#                         "PowerShell 7.4",
#                         ".NET 7.0",
#                         ".NET 8.0",
#                         "Microsoft Visual Studio 2022 version 17.6",
#                         "Microsoft Visual Studio 2022 version 17.4",
#                         "Microsoft Visual Studio 2022 version 17.8"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-21319",
#                     "affect": [
#                         ".NET 6.0",
#                         "Microsoft Visual Studio 2022 version 17.2",
#                         "Microsoft Visual Studio 2022 version 17.6",
#                         "Microsoft Visual Studio 2022 version 17.4",
#                         "Microsoft Visual Studio 2022 version 17.8",
#                         ".NET 7.0",
#                         ".NET 8.0",
#                         "Microsoft Identity Model v6.0.0 forNuget",
#                         "Microsoft Identity Model v7.0.0 for Nuget",
#                         "Microsoft Identity Model v6.0.0",
#                         "Microsoft Identity Model v5.0.0",
#                         "Microsoft Identity Model v7.0.0",
#                         "Microsoft Identity Model v5.0.0 for Nuget"
#                     ],
#                     "metrics": {
#                         "baseScore": 6.8,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-21409",
#                     "affect": [
#                         "Microsoft Visual Studio 2022 version 17.9",
#                         "Microsoft Visual Studio 2022 version 17.4",
#                         "Microsoft Visual Studio 2022 version 17.6",
#                         "Microsoft Visual Studio 2022 version 17.8",
#                         "PowerShell 7.3",
#                         "PowerShell 7.4",
#                         "PowerShell 7.2",
#                         ".NET 6.0",
#                         ".NET 7.0",
#                         ".NET 8.0",
#                         "Microsoft .NET Framework 4.8",
#                         "Microsoft .NET Framework 3.5 AND 4.8",
#                         "Microsoft .NET Framework 3.5 AND 4.7.2",
#                         "Microsoft .NET Framework 4.6.2/4.7/4.7.1/4.7.2",
#                         "Microsoft .NET Framework 3.5 AND 4.8.1",
#                         "Microsoft .NET Framework 4.6.2"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.3,
#                         "baseSeverity": "HIGH"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "VS Immersive Activate Helper",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2023-21267",
#                     "affect": [
#                         "Android"
#                     ],
#                     "metrics": {
#                         "baseScore": 5.5,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2023-1370",
#                     "affect": [
#                         "json-smart"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-21634",
#                     "affect": [
#                         "ion-java"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-20358",
#                     "affect": [
#                         "Cisco Adaptive Security Appliance (ASA) Software",
#                         "Cisco Firepower Threat Defense Software"
#                     ],
#                     "metrics": {
#                         "baseScore": 6.7,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 }
#             ]
#         },
#         {
#             "software": "vs_filehandler_amd64",
#             "vulnerabilities": [
#                 {
#                     "cve": "CVE-2023-1370",
#                     "affect": [
#                         "json-smart"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-21634",
#                     "affect": [
#                         "ion-java"
#                     ],
#                     "metrics": {
#                         "baseScore": 7.5,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-20353",
#                     "affect": [
#                         "Cisco Adaptive Security Appliance (ASA) Software",
#                         "Cisco Firepower Threat Defense Software"
#                     ],
#                     "metrics": {
#                         "baseScore": 8.6,
#                         "baseSeverity": "HIGH"
#                     }
#                 },
#                 {
#                     "cve": "CVE-2024-20358",
#                     "affect": [
#                         "Cisco Adaptive Security Appliance (ASA) Software",
#                         "Cisco Firepower Threat Defense Software"
#                     ],
#                     "metrics": {
#                         "baseScore": 6.7,
#                         "baseSeverity": "MEDIUM"
#                     }
#                 }
#             ]
#         }
#     ],
#     "analysisDate": "2024-05-09 13:37:56"
# }
# JSON guardado exitosamente en MongoDB.
# Error al guardar el JSON como archivo de texto: Object of type ObjectId is not JSON serializable
# LAPTOP-JorgeRodríguez
# Microsoft Teams Meeting Add-in for Microsoft Office
# CVE-2024-21374
# CVE-2024-29054
# CVE-2024-29053
# CVE-2024-29055
# Python 3.12.2 Standard Library (64-bit)
# Python 3.12.2 Executables (64-bit)
# Python 3.12.2 Test Suite (64-bit)
# Python 3.12.2 Tcl/Tk Support (64-bit)
# Python 3.12.2 Documentation (64-bit)
# Python 3.12.2 Add to Path (64-bit)
# CVE-2023-22943
# Python 3.12.2 pip Bootstrap (64-bit)
# CVE-2023-5752
# CVE-2023-5752
# CVE-2023-5752
# Python 3.12.2 Development Libraries (64-bit)
# Python 3.12.2 Core Interpreter (64-bit)
# CVE-2024-31868
# CVE-2024-31864
# CVE-2024-31868
# Office 16 Click-to-Run Extensibility Component
# CVE-2010-10007
# CVE-2024-32866
# CVE-2006-4242
# CVE-2006-4556
# CVE-2006-4378
# Office 16 Click-to-Run Localization Component
# CVE-2024-31983
# CVE-2012-10014
# CVE-2012-10013
# CVE-2010-10007
# Office 16 Click-to-Run Localization Component
# CVE-2024-31983
# CVE-2012-10014
# CVE-2012-10013
# CVE-2010-10007
# Office 16 Click-to-Run Licensing Component
# CVE-2010-10007
# CVE-2024-32866
# CVE-2006-4242
# CVE-2006-4556
# CVE-2006-4378
# Microsoft .NET Framework 4.5.1 Multi-Targeting Pack
# CVE-2024-21312
# Microsoft .NET Framework 4.8.1 Targeting Pack
# CVE-2024-21312
# Microsoft .NET Framework 4.5.2 Multi-Targeting Pack (ENU)
# CVE-2024-21312
# Windows SDK Desktop Headers x64
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# CVE-2023-40546
# CVE-2023-40547
# CVE-2023-40548
# CVE-2023-40549
# CVE-2023-40550
# CVE-2023-40551
# Microsoft .NET Runtime - 8.0.4 (x86)
# CVE-2024-26190
# CVE-2024-21392
# CVE-2024-21319
# CVE-2024-21409
# Microsoft.NET.Sdk.MacCatalyst.Manifest-8.0.100 (x64)
# CVE-2022-24512
# CVE-2022-24512
# CVE-2024-21409
# CVE-2023-40546
# CVE-2023-40547
# CVE-2023-40548
# CVE-2023-40549
# CVE-2023-40550
# CVE-2023-40551
# Windows Mobile Extension SDK Contracts
# CVE-2016-15012
# CVE-2024-34073
# CVE-2017-6099
# CVE-2017-20175
# Universal CRT Extension SDK
# CVE-2023-1579
# CVE-2024-34073
# CVE-2017-6099
# CVE-2017-20175
# Application Verifier x64 External Package (OnecoreUAP)
# CVE-2023-44487
# CVE-2022-20454
# Microsoft .NET Runtime - 6.0.29 (x64)
# CVE-2024-21392
# CVE-2024-26190
# CVE-2024-21386
# CVE-2024-21319
# Microsoft .NET Runtime - 6.0.29 (x86)
# CVE-2024-26190
# CVE-2024-21392
# CVE-2024-21319
# CVE-2024-21409
# Microsoft Visual Studio 2015 Shell (Isolated) Resources
# CVE-2024-0057
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-21386
# vs_githubprotocolhandlermsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20358
# CVE-2024-20359
# Visual C++ Library CRT Appx Resource Package
# CVE-2023-1579
# CVE-2014-9984
# CVE-2015-20109
# CVE-2018-11236
# CVE-2021-3999
# CVE-2024-2961
# CVE-2024-2961
# CVE-2023-5676
# Windows SDK for Windows Store Apps Metadata
# CVE-2024-27793
# CVE-2021-20373
# Microsoft .NET Toolset 7.0.118 (x64)
# CVE-2024-21319
# CVE-2022-24512
# CVE-2022-24512
# CVE-2023-40546
# CVE-2023-40547
# CVE-2023-40548
# CVE-2023-40549
# CVE-2023-40550
# CVE-2023-40551
# MySQL Examples and Samples 8.0
# CVE-2023-51714
# CVE-2024-25580
# CVE-2024-21000
# CVE-2024-20993
# CVE-2024-21061
# WinRT Intellisense Desktop - Other Languages
# CVE-2013-2465
# CVE-2011-3571
# CVE-2012-0507
# CVE-2017-16232
# CVE-2023-1370
# vs_communitysharedmsi
# CVE-2023-1370
# CVE-2024-21634
# CVE-2024-20353
# CVE-2024-20358
# SQL Server 2022 XEvent
# CVE-2024-29056
# CVE-2024-29988
# CVE-2024-29052
# CVE-2024-21345
# Windows SDK for Windows Store Apps Contracts
# CVE-2024-27793
# CVE-2021-20373
# Windows App Certification Kit Native Components
# CVE-2023-22943
# CVE-2016-4567
# CVE-2023-21118
# CVE-2023-21094
# Microsoft Visual Studio 2015 XAML Designer - ENU
# CVE-2024-20656
# CVE-2024-0056
# CVE-2024-0057
# CVE-2024-21386
# Windows SDK Desktop Headers arm
