# %%
Code crafted by: Yamid Felipe Quiroga González

# %%
#IMPORTED LIBRARIES
#requests is a library that allows us to make requests to APIS, this is essential for the project
#json is a library to modify the visual appearance of a json
#datetime is a library that contains time values, its use is mainly related to data access
#azurecosmos are libraries for connecting to the cosmos database in Azure, these allow us to access the database API to make queries
#os is a library that allows us to interact with the operating system where the program is executed
import json, requests, os
from datetime import datetime
import azure.cosmos.documents as documents
import azure.cosmos.cosmos_client as cosmos_client
import azure.cosmos.exceptions as exceptions
from azure.cosmos.partition_key import PartitionKey
from datetime import datetime
from windows_tools.installed_software import get_installed_software

# %%
# settings: Dictionary containing configurations for connecting to the Cosmos database on Azure.
#   - host: Address of the database host. Defaults to 'https://yamiddb.documents.azure.com:443/' if not provided in the 'ACCOUNT_HOST' environment variable.
#   - master_key: Master access key to the database. Defaults to the provided key if none is specified in the 'ACCOUNT_KEY' environment variable.
#   - database_id: ID of the database to connect to. Defaults to 'Vulnerabilities' if not provided in the 'COSMOS_DATABASE' environment variable.
#   - container_id: ID of the container in the database. Defaults to 'SoftwareList' if not provided in the 'COSMOS_CONTAINER' environment variable.

#Delete the """ to run the code
"""
settings = {
    'host': os.environ.get('ACCOUNT_HOST', ''),
    'master_key': os.environ.get('ACCOUNT_KEY', ''),
    'database_id': os.environ.get('COSMOS_DATABASE', 'Vulnerabilities'),
    'container_id': os.environ.get('COSMOS_CONTAINER', 'SoftwareList'),
}

# HOST: Address of the Cosmos database host on Azure.
HOST = settings['host']

# MASTER_KEY: Master access key to the Cosmos database on Azure.
MASTER_KEY = settings['master_key']

# DATABASE_ID: ID of the database to connect to.
DATABASE_ID = settings['database_id']

# CONTAINER_ID: ID of the container in the database.
CONTAINER_ID = settings['container_id']
"""

# %%
# Method to create or validate the information of cosmos database
def run_sample():
    client = cosmos_client.CosmosClient(HOST, {'masterKey': MASTER_KEY}, user_agent="CosmosDBPythonQuickstart", user_agent_overwrite=True)
    try:
        # setup database for this sample
        try:
            db = client.create_database(id=DATABASE_ID)
            print('Database with id \'{0}\' created'.format(DATABASE_ID))

        except exceptions.CosmosResourceExistsError:
            db = client.get_database_client(DATABASE_ID)
            print('Database with id \'{0}\' was found'.format(DATABASE_ID))

        # setup container for this sample
        try:
            container = db.create_container(id=CONTAINER_ID, partition_key=PartitionKey(path='/partitionKey'))
            print('Container with id \'{0}\' created'.format(CONTAINER_ID))

        except exceptions.CosmosResourceExistsError:
            container = db.get_container_client(CONTAINER_ID)
            print('Container with id \'{0}\' was found'.format(CONTAINER_ID))

    except exceptions.CosmosHttpResponseError as e:
        print('\nrun_sample has caught an error. {0}'.format(e.message))

    finally:
            print("\nrun_sample done")


if __name__ == '__main__':
    client = cosmos_client.CosmosClient(HOST, {'masterKey': MASTER_KEY}, user_agent="CosmosDBPythonQuickstart", user_agent_overwrite=True)
    try:
        # setup database for this sample
        try:
            db = client.create_database(id=DATABASE_ID)
            print('Database with id \'{0}\' created'.format(DATABASE_ID))

        except exceptions.CosmosResourceExistsError:
            db = client.get_database_client(DATABASE_ID)
            print('Database with id \'{0}\' was found'.format(DATABASE_ID))

        # setup container for this sample
        try:
            container = db.create_container(id=CONTAINER_ID, partition_key=PartitionKey(path='/partitionKey'))
            print('Container with id \'{0}\' created'.format(CONTAINER_ID))

        except exceptions.CosmosResourceExistsError:
            container = db.get_container_client(CONTAINER_ID)
            print('Container with id \'{0}\' was found'.format(CONTAINER_ID))

    except exceptions.CosmosHttpResponseError as e:
        print('\nrun_sample has caught an error. {0}'.format(e.message))

    finally:
            print("\nrun_sample done")
# Out:
# Database with id 'Vulnerabilities' was found
# Container with id 'SoftwareList' was found
#
# run_sample done

# %%
"""
Retrieves vulnerability information from the CVE Details API based on the specified software product ID and version ID.

Args:
    sw (str): The product ID of the software.
    vs (str): The version ID of the software.

Returns:
    dict: A dictionary containing vulnerability information retrieved from the API in JSON format.
"""
def apiVulnDb(sw, vs):

    url = f"https://www.cvedetails.com/api/v1/vulnerability/search?outputFormat=json&productId={sw}&versionId={vs}&pageNumber=1&resultsPerPage=20"

    payload = {}
    headers = {
        'accept': '',
        'accept-language': '',
        'cache-control': '',
        'cookie': '',
        'if-modified-since': '',
        'referer': '',
        'sec-ch-ua': '',
        'sec-ch-ua-mobile': '',
        'sec-ch-ua-platform': '',
        'sec-fetch-dest': '',
        'sec-fetch-mode': '',
        'sec-fetch-site': '',
        'sec-fetch-user': '',
        'upgrade-insecure-requests': '',
        'user-agent': '',
        'Authorization': ''
    }

    response = requests.request("GET", url, headers=headers, data=payload)
    return response.json()

# %%
"""
Retrieves information about a specific CVE (Common Vulnerabilities and Exposures) entry from the MITRE CVE database.

Args:
    cve (str): The CVE ID to retrieve information for.

Returns:
    dict: A dictionary containing information about the specified CVE entry in JSON format.

"""
def apiCVE(cve):
    return requests.get(f"https://cveawg.mitre.org/api/cve/{str(cve)}").json()

# %%
"""
Retrieves the list of affected products for a given CVE (Common Vulnerabilities and Exposures) entry.

Args:
    cve (str): The CVE ID to retrieve affected products for.

Returns:
    list or str: A list containing the names of affected products, or 'not found' if no affected products are found.

"""
def get_affected_products(cve):

    # Load the JSON data for the CVE
    dataCVE = apiCVE(cve)

    # Get the list of affected products from the JSON data
    affected_products = dataCVE['containers']['cna']['affected']

    # Create a list to store the product names
    product_list = []

    # Iterate over the list of affected products and extract the product names
    for affected_product in affected_products:
        product_list.append(affected_product['product'])

    # Return the list of products or 'not found' if the list is empty
    return product_list if product_list else 'not found'

# %%
"""
Retrieves CVSS (Common Vulnerability Scoring System) metrics for a given CVE (Common Vulnerabilities and Exposures) entry from the OpenCVE API.

Args:
    cve (str): The CVE ID to retrieve CVSS metrics for.

Returns:
    dict: A dictionary containing CVSS metrics for the specified CVE entry in JSON format.
"""
def apiCVEmetric(cve):

    payload = {}
    headers = {
        'Authorization': ''
    }
    url = f"https://www.opencve.io/api/cve/{cve}"
    response = requests.request("GET", url, headers=headers, data=payload)
    return response.json()

# %%
"""
Retrieves combined CVSS metrics for a given CVE (Common Vulnerabilities and Exposures) entry from the OpenCVE API.

Args:
    cve (str): The CVE ID to retrieve combined CVSS metrics for.

Returns:
    dict: A dictionary containing combined CVSS metrics for the specified CVE entry.

"""
def getMetric(cve):

    response = apiCVEmetric(cve)

    # Create a new dictionary to store the combined metrics
    new_metrics = {}

    # Check if the key "metrics" exists in the original JSON
    if "metrics" in response["raw_nvd_data"]:
        # Check if the key "cvssMetricV2" exists in "metrics"
        if "cvssMetricV2" in response["raw_nvd_data"]["metrics"]:
            new_metrics = response["raw_nvd_data"]["metrics"]["cvssMetricV2"]
        else:
            cvssMetricV2_data = []
        
        # Check if the key "cvssMetricV31" exists in "metrics"
        if "cvssMetricV31" in response["raw_nvd_data"]["metrics"]:
            new_metrics = response["raw_nvd_data"]["metrics"]["cvssMetricV31"]
        else:
            cvssMetricV31_data = []
    else:
        # If the key "metrics" does not exist, initialize both lists as empty
        cvssMetricV2_data = []
        cvssMetricV31_data = []
    
    return new_metrics

# %%
"""
Saves a JSON document in the Cosmos DB container.

Args:
    Swjson (dict): The JSON document to be saved.
"""
def saveJSON(Swjson):
    # Save the json in the container
    try:
        container = db.get_container_client(CONTAINER_ID)
        container.create_item(body = Swjson)
        print("Items already saved")
    except exceptions.CosmosResourceExistsError:
        print("Something wrong saving items")

# %%
"""
Searches for vulnerabilities associated with a specific software product and version,
retrieves relevant information, and saves it in the Cosmos DB container.

Args:
    product (str): The name of the software product.
    version (str): The version of the software product.

"""
def seachSWVulnerabilities(product, version):

    response = apiVulnDb(product, version)
    
    # Build the JSON document to be saved in the DB
    swVulnerabilities = {
        'id': f"{response['results'][0]['product']}_{version}_{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}",
        'partitionKey': 'partitionKey',
        "vulnerabilities": {} 
    }
    
    # Search in the VulnDB API response for CVEs and their titles to add this information to the new JSON
    for result in response['results']:
        cve_id = result['cveId']
        print(cve_id)
        swVulnerabilities["vulnerabilities"][cve_id] = {
            "summary": result["summary"],
            "affect": get_affected_products(cve_id), 
            "metrics": getMetric(cve_id)
        }

    # Save data
    saveJSON(swVulnerabilities)
    
    # Print the JSON result
    print(json.dumps(swVulnerabilities, indent=4))

# %%
seachSWVulnerabilities("320","684235")
#seachSWVulnerabilities("19117","1752412")
# Out:
# CVE-2024-21413
# CVE-2024-21379
# CVE-2024-21378
# CVE-2024-20677
# CVE-2024-20673
# CVE-2023-41764
# CVE-2023-36897
# CVE-2023-36896
# CVE-2023-36895
# CVE-2023-36893
# CVE-2023-36884
# CVE-2023-36866
# CVE-2023-36865
# CVE-2023-36767
# CVE-2023-36766
# CVE-2023-36765
# CVE-2023-36763
# CVE-2023-36762
# CVE-2023-36761
# CVE-2023-36569
# Items already saved
# {
#     "id": "Office_684235_2024-04-15 20:42:29",
#     "partitionKey": "partitionKey",
#     "vulnerabilities": {
#         "CVE-2024-21413": {
#             "summary": "Microsoft Outlook Remote Code Execution Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Office 2016"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 9.8,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "CRITICAL",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "NONE",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 3.9
#                 }
#             ]
#         },
#         "CVE-2024-21379": {
#             "summary": "Microsoft Word Remote Code Execution Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Word 2016"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.8,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2024-21378": {
#             "summary": "Microsoft Outlook Remote Code Execution Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Outlook 2016"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 8.8,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "NONE",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "LOW",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 2.8
#                 }
#             ]
#         },
#         "CVE-2024-20677": {
#             "summary": "A security vulnerability exists in FBX that could lead to remote code execution. To mitigate this vulnerability, the ability to insert FBX files has been disabled in Word, Excel, PowerPoint and Outlook for Windows and Mac. Versions of Office that had this feature enabled will no longer have access to it. This includes Office 2019, Office 2021, Office LTSC for Mac 2021, and Microsoft 365. As of February 13, 2024, the ability to insert FBX files has also been disabled in 3D Viewer.\n3D models in Office documents that were previously inserted from a FBX file will continue to work as expected unless the Link to File option was chosen at insert time.\nThis change is effective as of the January 9, 2024 security update.",
#             "affect": [
#                 "3D Viewer",
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC for Mac 2021",
#                 "Microsoft Office LTSC 2021"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.8,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2024-20673": {
#             "summary": "Microsoft Office Remote Code Execution Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Excel 2016",
#                 "Microsoft Office 2016",
#                 "Microsoft PowerPoint 2016",
#                 "Microsoft Visio 2016",
#                 "Microsoft Word 2016",
#                 "Microsoft Publisher 2016",
#                 "Skype for Business 2016"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.8,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2023-41764": {
#             "summary": "Microsoft Office Spoofing Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Office 2016",
#                 "Microsoft Office 2013 Service Pack 1"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 5.5,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "MEDIUM",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:N/I:H/A:N",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "NONE",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "NONE"
#                     },
#                     "impactScore": 3.6,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2023-36897": {
#             "summary": "Visual Studio Tools for Office Runtime Spoofing Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Visual Studio 2017 version 15.9 (includes 15.0 - 15.8)",
#                 "Microsoft Visual Studio 2022 version 17.2",
#                 "Microsoft Visual Studio 2019 version 16.11 (includes 16.0 - 16.10)",
#                 "Microsoft Visual Studio 2022 version 17.4",
#                 "Microsoft Visual Studio 2022 version 17.6",
#                 "Visual Studio 2010 Tools for Office Runtime"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "nvd@nist.gov",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 6.5,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "MEDIUM",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:N/I:H/A:N",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "NONE",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "NONE"
#                     },
#                     "impactScore": 3.6,
#                     "exploitabilityScore": 2.8
#                 },
#                 {
#                     "type": "Secondary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 8.1,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:N",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "NONE",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.2,
#                     "exploitabilityScore": 2.8
#                 }
#             ]
#         },
#         "CVE-2023-36896": {
#             "summary": "Microsoft Excel Remote Code Execution Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft Office 2019 for Mac",
#                 "Microsoft Office Online Server",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC for Mac 2021",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Excel 2016",
#                 "Microsoft Excel 2013 Service Pack 1"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.8,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2023-36895": {
#             "summary": "Microsoft Outlook Remote Code Execution Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft Office 2019 for Mac",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC for Mac 2021",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Office 2016",
#                 "Microsoft Word 2013 Service Pack 1",
#                 "Microsoft Word 2013 Service Pack 1 "
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.8,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2023-36893": {
#             "summary": "Microsoft Outlook Spoofing Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Outlook 2016",
#                 "Microsoft Outlook 2013 Service Pack 1"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 6.5,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "MEDIUM",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:H/I:N/A:N",
#                         "integrityImpact": "NONE",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "NONE",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 3.6,
#                     "exploitabilityScore": 2.8
#                 }
#             ]
#         },
#         "CVE-2023-36884": {
#             "summary": "Windows Search Remote Code Execution Vulnerability",
#             "affect": [
#                 "Windows 10 Version 1809",
#                 "Windows Server 2019",
#                 "Windows Server 2019 (Server Core installation)",
#                 "Windows Server 2022",
#                 "Windows 11 version 21H2",
#                 "Windows 10 Version 21H2",
#                 "Windows 11 version 22H2",
#                 "Windows 10 Version 22H2",
#                 "Windows 10 Version 1507",
#                 "Windows 10 Version 1607",
#                 "Windows Server 2016",
#                 "Windows Server 2016 (Server Core installation)",
#                 "Windows Server 2008 Service Pack 2",
#                 "Windows Server 2008 Service Pack 2 (Server Core installation)",
#                 "Windows Server 2008  Service Pack 2",
#                 "Windows Server 2008 R2 Service Pack 1",
#                 "Windows Server 2008 R2 Service Pack 1 (Server Core installation)",
#                 "Windows Server 2012",
#                 "Windows Server 2012 (Server Core installation)",
#                 "Windows Server 2012 R2",
#                 "Windows Server 2012 R2 (Server Core installation)"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.5,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:N/AC:H/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "HIGH",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.6
#                 },
#                 {
#                     "type": "Secondary",
#                     "source": "nvd@nist.gov",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 8.8,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 2.8
#                 }
#             ]
#         },
#         "CVE-2023-36866": {
#             "summary": "Microsoft Office Visio Remote Code Execution Vulnerability",
#             "affect": [
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office 2019",
#                 "Microsoft Visio 2016"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.8,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2023-36865": {
#             "summary": "Microsoft Office Visio Remote Code Execution Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft 365 Apps for Enterprise"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.8,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2023-36767": {
#             "summary": "Microsoft Office Security Feature Bypass Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft Office 2019 for Mac",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC for Mac 2021",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Office 2016",
#                 "Microsoft Office 2013 Service Pack 1"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "nvd@nist.gov",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 4.3,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "MEDIUM",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:N/I:N/A:L",
#                         "integrityImpact": "NONE",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "LOW",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "NONE"
#                     },
#                     "impactScore": 1.4,
#                     "exploitabilityScore": 2.8
#                 },
#                 {
#                     "type": "Secondary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 4.3,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "MEDIUM",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:N/I:N/A:L",
#                         "integrityImpact": "NONE",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "LOW",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "NONE"
#                     },
#                     "impactScore": 1.4,
#                     "exploitabilityScore": 2.8
#                 }
#             ]
#         },
#         "CVE-2023-36766": {
#             "summary": "Microsoft Excel Information Disclosure Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft Office 2019 for Mac",
#                 "Microsoft Office Online Server",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC for Mac 2021",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Excel 2016",
#                 "Microsoft Excel 2013 Service Pack 1"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "nvd@nist.gov",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 5.5,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "MEDIUM",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:N/A:N",
#                         "integrityImpact": "NONE",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "NONE",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 3.6,
#                     "exploitabilityScore": 1.8
#                 },
#                 {
#                     "type": "Secondary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.8,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2023-36765": {
#             "summary": "Microsoft Office Elevation of Privilege Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "nvd@nist.gov",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 9.8,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "CRITICAL",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "NONE",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 3.9
#                 },
#                 {
#                     "type": "Secondary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.8,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:L/UI:N/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "NONE",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "LOW",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2023-36763": {
#             "summary": "Microsoft Outlook Information Disclosure Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Outlook 2016"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.5,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:N/A:N",
#                         "integrityImpact": "NONE",
#                         "userInteraction": "NONE",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "NONE",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 3.6,
#                     "exploitabilityScore": 3.9
#                 }
#             ]
#         },
#         "CVE-2023-36762": {
#             "summary": "Microsoft Word Remote Code Execution Vulnerability",
#             "affect": [
#                 "Microsoft SharePoint Enterprise Server 2016",
#                 "Microsoft Office 2019",
#                 "Microsoft Office 2019 for Mac",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC for Mac 2021",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Word 2016"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 7.3,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:L",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "LOW",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.5,
#                     "exploitabilityScore": 1.8
#                 }
#             ]
#         },
#         "CVE-2023-36761": {
#             "summary": "Microsoft Word Information Disclosure Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC 2021",
#                 "Microsoft Word 2016",
#                 "Microsoft Word 2013 Service Pack 1",
#                 "Microsoft Word 2013 Service Pack 1 "
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "nvd@nist.gov",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 5.3,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "MEDIUM",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:L/I:N/A:N",
#                         "integrityImpact": "NONE",
#                         "userInteraction": "NONE",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "NONE",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "LOW"
#                     },
#                     "impactScore": 1.4,
#                     "exploitabilityScore": 3.9
#                 },
#                 {
#                     "type": "Secondary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 6.5,
#                         "attackVector": "NETWORK",
#                         "baseSeverity": "MEDIUM",
#                         "vectorString": "CVSS:3.1/AV:N/AC:L/PR:N/UI:R/S:U/C:H/I:N/A:N",
#                         "integrityImpact": "NONE",
#                         "userInteraction": "REQUIRED",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "NONE",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 3.6,
#                     "exploitabilityScore": 2.8
#                 }
#             ]
#         },
#         "CVE-2023-36569": {
#             "summary": "Microsoft Office Elevation of Privilege Vulnerability",
#             "affect": [
#                 "Microsoft Office 2019",
#                 "Microsoft 365 Apps for Enterprise",
#                 "Microsoft Office LTSC 2021"
#             ],
#             "metrics": [
#                 {
#                     "type": "Primary",
#                     "source": "secure@microsoft.com",
#                     "cvssData": {
#                         "scope": "UNCHANGED",
#                         "version": "3.1",
#                         "baseScore": 8.4,
#                         "attackVector": "LOCAL",
#                         "baseSeverity": "HIGH",
#                         "vectorString": "CVSS:3.1/AV:L/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H",
#                         "integrityImpact": "HIGH",
#                         "userInteraction": "NONE",
#                         "attackComplexity": "LOW",
#                         "availabilityImpact": "HIGH",
#                         "privilegesRequired": "NONE",
#                         "confidentialityImpact": "HIGH"
#                     },
#                     "impactScore": 5.9,
#                     "exploitabilityScore": 2.5
#                 }
#             ]
#         }
#     }
# }

# %%
for software in get_installed_software():
    print(software)
# Out:
# {'name': 'Cisco Packet Tracer 8.2.1 64Bit', 'version': '8.2.1.118', 'publisher': 'Cisco Systems, Inc.'}
# {'name': 'GDR 1105 para SQL Server 2022 (KB5029379) (64-bit)', 'version': '16.0.1105.1', 'publisher': 'Microsoft Corporation'}
# {'name': 'GDR 1110 para SQL Server 2022 (KB5032968) (64-bit)', 'version': '16.0.1110.1', 'publisher': 'Microsoft Corporation'}
# {'name': 'GDR 1115 para SQL Server 2022 (KB5035432) (64-bit)', 'version': '16.0.1115.1', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Azure Compute Emulator - v2.9.7', 'version': '2.9.8999.43', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft SQL Server 2022 (64-bit)', 'version': '', 'publisher': ''}
# {'name': 'Microsoft SQL Server 2022 (64-bit)', 'version': '', 'publisher': 'Microsoft Corporation'}
# {'name': '', 'version': '', 'publisher': 'Microsoft Corporation'}
# {'name': '', 'version': '', 'publisher': 'Microsoft Corporation'}
# {'name': 'Aplicaciones de Microsoft 365 para empresas - es-es', 'version': '16.0.17425.20146', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft OneDrive', 'version': '24.055.0317.0002', 'publisher': 'Microsoft Corporation'}
# {'name': 'Riot Vanguard', 'version': '', 'publisher': 'Riot Games, Inc.'}
# {'name': '', 'version': '', 'publisher': 'Microsoft Corporation'}
# {'name': 'Realm of the Mad God Exalt', 'version': '', 'publisher': 'Wild Shadow Studios'}
# {'name': 'Dead Island Riptide Definitive Edition', 'version': '', 'publisher': 'Techland'}
# {'name': 'Counter-Strike 2', 'version': '', 'publisher': 'Valve'}
# {'name': 'Microsoft Azure Compute Emulator - v2.9.7', 'version': '2.9.8999.43', 'publisher': 'Microsoft Corporation'}
# {'name': 'IIS Express Application Compatibility Database for x64', 'version': '', 'publisher': ''}
# {'name': 'Microsoft.NET.Workload.Mono.Toolchain.net6.Manifest (x64)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 Executables (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': 'SQL Server 2022 SQL Diagnostics', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft ODBC Driver 17 for SQL Server', 'version': '17.10.6.1', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_minshellx64msi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Toolset 8.0.200 (x64)', 'version': '32.7.48173', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Shared Management Objects', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Database Engine Shared', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET 8.0 Templates 8.0.200 (x64)', 'version': '32.7.48173', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Sdk.iOS.Manifest-8.0.100 (x64)', 'version': '17.2.8004', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.38.33130', 'version': '14.38.33130', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2010  x64 Redistributable - 10.0.40219', 'version': '10.0.40219', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET AppHost Pack - 8.0.2 (x64_x86)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Workload.Emscripten.net7.Manifest (x64)', 'version': '64.8.8705', 'publisher': 'Microsoft Corporation'}
# {'name': 'Java 8 Update 51 (64-bit)', 'version': '8.0.510', 'publisher': 'Oracle Corporation'}
# {'name': 'vs_communityx64msi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Host - 8.0.2 (x64)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Sdk.tvOS.Manifest-8.0.100 (x64)', 'version': '17.2.8004', 'publisher': 'Microsoft Corporation'}
# {'name': 'icecap_collection_x64', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Full text search', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Shared Management Objects Extensions', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET SDK 8.0.200 (x64) from Visual Studio', 'version': '8.2.24.6925', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft SQL Server 2019 LocalDB ', 'version': '15.0.4153.1', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft System CLR Types para SQL Server 2019', 'version': '15.0.2000.5', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2012 x64 Additional Runtime - 11.0.61030', 'version': '11.0.61030', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Workload.Emscripten.Current.Manifest (x64)', 'version': '64.8.8705', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Azure PowerShell - April 2018', 'version': '5.7.0.18831', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Azure Libraries for .NET – v2.9', 'version': '3.0.2310.23', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Command Line Utilities 15 for SQL Server', 'version': '15.0.1300.359', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 Core Interpreter (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': 'Logitech G HUB', 'version': '2024.2.534136', 'publisher': 'Logitech'}
# {'name': 'Universal CRT Tools x64', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft OLE DB Driver for SQL Server', 'version': '18.7.2.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Application Verifier x64 External Package (DesktopEditions)', 'version': '10.1.22621.2428', 'publisher': 'Microsoft'}
# {'name': 'Microsoft .NET Targeting Pack - 8.0.2 (x64)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 DMF', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft SQL Server 2022 RsFx Driver', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Advanced Analytics', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows App Certification Kit Native Components', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Azure Data Studio', 'version': '1.47.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Database Engine Services', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Common Files', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET AppHost Pack - 8.0.2 (x64)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Sdk.Android.Manifest-8.0.100 (x64)', 'version': '34.0.52', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual Studio Installer', 'version': '3.9.2164.57262', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Shared Management Objects', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Java(TM) SE Development Kit 21.0.1 (64-bit)', 'version': '21.0.1.0', 'publisher': 'Oracle Corporation'}
# {'name': 'SQL Server 2022 Connection Info', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET AppHost Pack - 8.0.2 (x64_arm64)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Update for Windows 10 for x64-based Systems (KB5001716)', 'version': '8.93.0.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Analysis Services OLE DB Provider', 'version': '16.0.5143.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Batch Parser', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft MPI (10.1.12498.18)', 'version': '10.1.12498.18', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Common Files', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Oracle VM VirtualBox 7.0.14', 'version': '7.0.14', 'publisher': 'Oracle and/or its affiliates'}
# {'name': 'Microsoft Visual Studio Tools for Applications 2019 x64 Hosting Support', 'version': '16.0.31110', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_devenx64vmsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Office 16 Click-to-Run Licensing Component', 'version': '16.0.17425.20146', 'publisher': 'Microsoft Corporation'}
# {'name': 'Office 16 Click-to-Run Extensibility Component', 'version': '16.0.17425.20146', 'publisher': 'Microsoft Corporation'}
# {'name': 'Office 16 Click-to-Run Localization Component', 'version': '16.0.17425.20146', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Azure Authoring Tools - v2.9.7', 'version': '2.9.8999.45', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 Test Suite (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': 'SQL Server 2022 XEvent', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Shared Management Objects Extensions', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'IIS 10.0 Express', 'version': '10.0.08608', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Workload.Mono.Toolchain.net7.Manifest (x64)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Standard Targeting Pack - 2.1.0 (x64)', 'version': '24.0.28113', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft VSS Writer for SQL Server 2022', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'IIS Express Application Compatibility Database for x86', 'version': '', 'publisher': ''}
# {'name': 'Microsoft Visual C++ 2022 X64 Debug Runtime - 14.38.33135', 'version': '14.38.33135', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_Graphics_Singletonx64', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'NVIDIA Controlador de gráficos 552.12', 'version': '552.12', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA GeForce Experience 3.27.0.120', 'version': '3.27.0.120', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Optimus Update 39.5.0.0', 'version': '39.5.0.0', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Software del sistema PhysX 9.21.0713', 'version': '9.21.0713', 'publisher': 'NVIDIA Corporation'}
# {'name': 'Actualización de NVIDIA 39.5.0.0', 'version': '39.5.0.0', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA FrameView SDK 1.3.8513.32290073', 'version': '1.3.8513.32290073', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA SHIELD Streaming', 'version': '7.1.32568680', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA GPX Common OSS binaries (POCO, OpenSSL, libprotobuf)', 'version': '7.1', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Controlador de audio HD 1.3.40.14', 'version': '1.3.40.14', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Install Application', 'version': '2.1002.413.0', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Backend', 'version': '39.5.0.0', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Container', 'version': '1.37', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA TelemetryApi helper for NvContainer', 'version': '1.37', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA LocalSystem Container', 'version': '1.37', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Message Bus for NvContainer', 'version': '1.34', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA NVAPI Monitor plugin for NvContainer', 'version': '1.0', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA NetworkService Container', 'version': '1.37', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Session Container', 'version': '1.37', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA User Container', 'version': '1.37', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA NvModuleTracker', 'version': '6.14.25214.24630', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA NodeJS', 'version': '3.27.0.120', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Watchdog Plugin for NvContainer', 'version': '1.37', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Telemetry Client', 'version': '17.1.7.0', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Virtual Host Controller', 'version': '3.05.0.1', 'publisher': 'NVIDIA Corporation'}
# {'name': 'Nvidia Share', 'version': '3.27.0.120', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA ShadowPlay 3.27.0.120', 'version': '3.27.0.120', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA SHIELD Wireless Controller Driver', 'version': '3.27.0.116', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Update Core', 'version': '39.5.0.0', 'publisher': 'NVIDIA Corporation'}
# {'name': 'NVIDIA Virtual Audio 4.49.0.0', 'version': '4.49.0.0', 'publisher': 'NVIDIA Corporation'}
# {'name': 'Microsoft Windows Desktop Targeting Pack - 8.0.2 (x64)', 'version': '64.8.8806', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 Tcl/Tk Support (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': 'Microsoft .NET Host FX Resolver - 8.0.2 (x64)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 Documentation (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': 'SQL Server 2022 XEvent', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 pip Bootstrap (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': 'Microsoft.NET.Sdk.MacCatalyst.Manifest-8.0.100 (x64)', 'version': '17.2.8004', 'publisher': 'Microsoft Corporation'}
# {'name': 'VS JIT Debugger', 'version': '17.0.125.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2022 X64 Additional Runtime - 14.38.33130', 'version': '14.38.33130', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Database Engine Services', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Workload.Mono.Toolchain.Current.Manifest (x64)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Update Health Tools', 'version': '5.72.0.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Runtime - 8.0.2 (x64)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Web Deploy 4.0', 'version': '10.0.7421', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Workload.Emscripten.net6.Manifest (x64)', 'version': '64.8.8705', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2012 x64 Minimum Runtime - 11.0.61030', 'version': '11.0.61030', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK DirectX x64 Remote', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_minshellinteropx64msi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Windows Desktop Runtime - 8.0.2 (x64)', 'version': '64.8.8806', 'publisher': 'Microsoft Corporation'}
# {'name': 'VS Script Debugging Common', 'version': '17.0.125.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Database Engine Shared', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Sdk.macOS.Manifest-8.0.100 (x64)', 'version': '14.2.8004', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 DMF', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 Standard Library (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': '', 'version': '255.255.65535.0', 'publisher': ''}
# {'name': 'Microsoft SQL Server 2022 Setup (English)', 'version': '16.0.1115.1', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server 2022 Connection Info', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft ASP.NET Core 8.0.2 Targeting Pack (x64)', 'version': '8.0.2.24068', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft.NET.Sdk.Maui.Manifest-8.0.100 (x64)', 'version': '8.0.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft ASP.NET Core Module V2 for IIS Express', 'version': '17.0.22116.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 Development Libraries (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': 'Microsoft.NET.Sdk.Aspire.Manifest-8.0.100 (x64)', 'version': '64.0.5426', 'publisher': 'Microsoft Corporation'}
# {'name': 'Application Verifier x64 External Package (OnecoreUAP)', 'version': '10.1.22621.2428', 'publisher': 'Microsoft'}
# {'name': 'IntelliTraceProfilerProxy', 'version': '15.0.21225.01', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft ASP.NET Core Module for IIS Express', 'version': '12.2.18292.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft ASP.NET Core 8.0.2 Shared Framework (x64)', 'version': '8.0.2.24068', 'publisher': 'Microsoft Corporation'}
# {'name': 'DiagnosticsHub_CollectionService', 'version': '17.3.32601', 'publisher': 'Microsoft Corporation'}
# {'name': 'Visual Studio Community 2022', 'version': '17.9.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'FileZilla 3.66.5', 'version': '3.66.5', 'publisher': 'Tim Kosse'}
# {'name': 'IntelliJ IDEA Community Edition 2023.2.5', 'version': '232.10227.8', 'publisher': 'JetBrains s.r.o.'}
# {'name': 'Microsoft Edge', 'version': '123.0.2420.97', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Edge Update', 'version': '1.3.185.29', 'publisher': ''}
# {'name': 'WebView2 Runtime de Microsoft Edge', 'version': '123.0.2420.97', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Help Viewer 2.3', 'version': '2.3.28307', 'publisher': 'Microsoft Corporation'}
# {'name': 'Npcap', 'version': '1.78', 'publisher': 'Nmap Project'}
# {'name': 'Steam', 'version': '2.10.91.91', 'publisher': 'Valve Corporation'}
# {'name': 'TLauncher', 'version': '2.885', 'publisher': 'TLauncher Inc.'}
# {'name': 'Wireshark 4.2.2 x64', 'version': '4.2.2', 'publisher': 'The Wireshark developer community, https://www.wireshark.org'}
# {'name': 'Windows IoT Extension SDK Contracts', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_vswebprotocolselectormsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_BlendMsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'WinRT Intellisense UAP - en-us', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual Studio Setup WMI Provider', 'version': '3.9.2148.60653', 'publisher': 'Microsoft Corporation'}
# {'name': 'Visual Studio 2017 Isolated Shell for SSMS', 'version': '15.0.28308.421', 'publisher': 'Microsoft Corporation'}
# {'name': '3CXPhone', 'version': '4.0.26523.0', 'publisher': '3CX'}
# {'name': 'Windows Mobile Extension SDK Contracts', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft SQL Server Management Studio - 19.2', 'version': '19.2.56.2', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Framework 4.7.2 Targeting Pack', 'version': '4.7.03062', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_CoreEditorFonts', 'version': '17.7.40001', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_filehandler_amd64', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2015-2022 Redistributable (x64) - 14.38.33130', 'version': '14.38.33130.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'WPTx64 (OnecoreUAP)', 'version': '10.1.22621.2428', 'publisher': 'Microsoft'}
# {'name': 'Universal CRT Redistributable', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'ClickOnce Bootstrapper Package for Microsoft .NET Framework', 'version': '4.8.09037', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows Mobile Extension SDK', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2015-2022 Redistributable (x86) - 14.38.33130', 'version': '14.38.33130.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2022 X86 Debug Runtime - 14.38.33135', 'version': '14.38.33135', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Desktop Libs arm64', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK for Windows Store Apps DirectX x86 Remote', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'WinRT Intellisense IoT - en-us', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2012 Redistributable (x86) - 11.0.61030', 'version': '11.0.61030.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Desktop Headers x64', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_communitysharedmsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python Launcher', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': 'Windows SDK Desktop Libs x86', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows App Certification Kit x64', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_clickoncebootstrappermsires', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Paquete de compatibilidad de Microsoft .NET Framework 4.8 (español)', 'version': '4.8.03761', 'publisher': 'Microsoft Corporation'}
# {'name': 'icecap_collectionresources', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_vswebprotocolselectormsires', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_Graphics_Singletonx86', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'WinRT Intellisense PPI - Other Languages', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Java Auto Updater', 'version': '2.8.51.16', 'publisher': 'Oracle Corporation'}
# {'name': 'Universal General MIDI DLS Extension SDK', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Desktop Headers x86', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'icecap_collection_neutral', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'MSI Development Tools', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'WPT Redistributables', 'version': '10.1.22621.2428', 'publisher': 'Microsoft'}
# {'name': 'WinRT Intellisense IoT - Other Languages', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft ASP.NET Core 8.0.2 Targeting Pack (x86)', 'version': '8.0.2.24068', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_minshellinteropsharedmsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Desktop Headers arm', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows Team Extension SDK Contracts', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'WPTx64 (DesktopEditions)', 'version': '10.1.22621.2428', 'publisher': 'Microsoft'}
# {'name': 'Microsoft .NET Framework 4.8 SDK (español)', 'version': '4.8.03761', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Desktop Headers arm64', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK AddOn', 'version': '10.1.0.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2022 X86 Additional Runtime - 14.38.33130', 'version': '14.38.33130', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Signing Tools', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'WinAppDeploy', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server Management Studio Language Pack - English', 'version': '19.2.56.2', 'publisher': 'Microsoft Corp.'}
# {'name': 'Windows SDK Desktop Libs x64', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_githubprotocolhandlermsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK for Windows Store Apps Headers', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual Studio Setup Configuration', 'version': '3.9.2148.60653', 'publisher': 'Microsoft Corporation'}
# {'name': 'WinRT Intellisense Mobile - en-us', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Universal CRT Headers Libraries and Sources', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK ARM Desktop Tools', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft NetStandard SDK', 'version': '15.0.51105', 'publisher': 'Microsoft Corporation'}
# {'name': 'WinRT Intellisense Desktop - en-us', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK EULA', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporations'}
# {'name': 'Windows SDK for Windows Store Apps Libs', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows Software Development Kit - Windows 10.0.22621.2428', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Kits Configuration Installer', 'version': '10.1.22621.2428', 'publisher': 'Microsoft'}
# {'name': 'vcpp_crt.redist.clickonce', 'version': '14.38.33135', 'publisher': 'Microsoft Corporation'}
# {'name': 'WinRT Intellisense Desktop - Other Languages', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Modern Versioned Developer Tools', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_minshellmsires', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_minshellsharedmsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_communitymsires', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Targeting Pack - 8.0.2 (x86)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2013 x86 Minimum Runtime - 12.0.40664', 'version': '12.0.40664', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Windows Desktop Runtime - 8.0.2 (x86)', 'version': '64.8.8806', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft TestPlatform SDK Local Feed', 'version': '17.0.0.5175695', 'publisher': 'Microsoft'}
# {'name': 'Paquete acumulativo de Intellisense de Microsoft .NET Framework para Visual Studio (español)', 'version': '4.8.09037', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK for Windows Store Apps Contracts', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Host FX Resolver - 8.0.2 (x86)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Analysis Services OLE DB Provider', 'version': '16.0.5143.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Universal CRT Tools x86', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft ASP.NET Diagnostic Pack for Visual Studio', 'version': '17.9.195.45391', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK for Windows Store Apps Tools', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK DirectX x86 Remote', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK for Windows Store Apps', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_clickoncebootstrappermsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Framework 4.8 SDK', 'version': '4.8.03928', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Help Viewer 2.3', 'version': '2.3.28307', 'publisher': 'Microsoft Corporation'}
# {'name': 'SDK ARM Additions', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Desktop Libs arm', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2013 Redistributable (x86) - 12.0.40664', 'version': '12.0.40664.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK for Windows Store Managed Apps Libs', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'WinRT Intellisense PPI - en-us', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Desktop Tools x86', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_clickoncesigntoolmsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Modern Non-Versioned Developer Tools', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Desktop Tools arm64', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Host - 8.0.2 (x86)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2012 x86 Additional Runtime - 11.0.61030', 'version': '11.0.61030', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows Desktop Extension SDK', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'icecap_collectionresourcesx64', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft ASP.NET Core 8.0.2 Shared Framework (x86)', 'version': '8.0.2.24068', 'publisher': 'Microsoft Corporation'}
# {'name': 'SDK ARM Redistributables', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'SSMS Post Install Tasks', 'version': '19.2.56.2', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows Desktop Extension SDK Contracts', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Framework 4.8 Targeting Pack', 'version': '4.8.03761', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2012 x86 Minimum Runtime - 11.0.61030', 'version': '11.0.61030', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows App Certification Kit x64 (OnecoreUAP)', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'WinRT Intellisense UAP - Other Languages', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows Team Extension SDK', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft .NET Runtime - 8.0.2 (x86)', 'version': '64.8.8795', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK for Windows Store Apps Metadata', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows IoT Extension SDK', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Redistributables', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'IntelliTraceProfilerProxy', 'version': '15.0.21225.01', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2012 Redistributable (x64) - 11.0.61030', 'version': '11.0.61030.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Integration Services', 'version': '16.0.5395.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_SQLClickOnceBootstrappermsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Facade Windows WinMD Versioned', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2013 x86 Additional Runtime - 12.0.40664', 'version': '12.0.40664', 'publisher': 'Microsoft Corporation'}
# {'name': 'SQL Server Management Studio', 'version': '19.2.56.2', 'publisher': 'Microsoft Corp.'}
# {'name': 'Windows App Certification Kit SupportedApiList x86', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Universal CRT Extension SDK', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Paquete de compatibilidad de Microsoft .NET Framework 4.7.2 (español)', 'version': '4.7.03062', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.38.33130', 'version': '14.38.33130', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_FileTracker_Singleton', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Windows Desktop Targeting Pack - 8.0.2 (x86)', 'version': '64.8.8806', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual Studio Tools for Applications 2019 x86 Hosting Support', 'version': '16.0.31110', 'publisher': 'Microsoft Corporation'}
# {'name': 'Windows SDK Desktop Tools x64', 'version': '10.1.22621.2428', 'publisher': 'Microsoft Corporation'}
# {'name': 'Entity Framework 6.2.0 Tools  for Visual Studio 2022', 'version': '6.2.0.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual C++ 2010  x86 Redistributable - 10.0.40219', 'version': '10.0.40219', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_tipsmsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Microsoft Visual Studio Tools for Applications 2019', 'version': '16.0.31110', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_filehandler_x86', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'vs_devenvsharedmsi', 'version': '17.9.34511', 'publisher': 'Microsoft Corporation'}
# {'name': 'Browser for SQL Server 2022', 'version': '16.0.1000.6', 'publisher': 'Microsoft Corporation'}
# {'name': 'VS Immersive Activate Helper', 'version': '17.0.125.0', 'publisher': 'Microsoft Corporation'}
# {'name': 'Discord', 'version': '1.0.9024', 'publisher': 'Discord Inc.'}
# {'name': 'Postman x86_64 10.24.16', 'version': '10.24.16', 'publisher': 'Postman'}
# {'name': 'Riot Client ', 'version': '', 'publisher': 'Riot Games, Inc'}
# {'name': 'VALORANT', 'version': '', 'publisher': 'Riot Games, Inc'}
# {'name': 'Microsoft Visual Studio Code (User)', 'version': '1.87.2', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
# {'name': 'Discord', 'version': '1.0.9024', 'publisher': 'Discord Inc.'}
# {'name': 'Postman x86_64 10.24.16', 'version': '10.24.16', 'publisher': 'Postman'}
# {'name': 'Riot Client ', 'version': '', 'publisher': 'Riot Games, Inc'}
# {'name': 'VALORANT', 'version': '', 'publisher': 'Riot Games, Inc'}
# {'name': 'Microsoft Visual Studio Code (User)', 'version': '1.87.2', 'publisher': 'Microsoft Corporation'}
# {'name': 'Python 3.12.2 (64-bit)', 'version': '3.12.2150.0', 'publisher': 'Python Software Foundation'}
